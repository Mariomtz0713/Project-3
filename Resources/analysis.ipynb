# %% [markdown]
# ## Analyzing Data

# %%
import pandas as pd
import json

# %%
# Reading json data into dataframe
df = pd.read_json('DataFiles/clean_data.json')
df
# Out:
#     origin destination  price airline  flight_number
# 0      SAT         LAX    280      NK           1044  \
# 1      SAT         LAS    126      F9           2075
# 2      SAT         BWI    150      NK           1739
# 3      SAT         LAS    115      F9           2075
# 4      SAT         LAS    170      F9           2075
# ..     ...         ...    ...     ...            ...
# 330    SAT         ORL   1823      UA           2496
# 331    SAT         HNL    668      UA           2486
# 332    SAT         YYC    566      UA           2486
# 333    SAT         PHX    384      UA           2460
# 334    SAT         ATH   1690      UA           2010
#
#                   departure_at                  return_at  transfers
# 0    2023-07-20T22:28:00-05:00  2023-08-01T07:15:00-07:00          0  \
# 1    2023-07-21T22:11:00-05:00  2023-07-28T16:26:00-07:00          0
# 2    2023-07-22T16:00:00-05:00  2023-08-05T21:19:00-04:00          0
# ...

# %%
# Finding popular airlines
df['airline'].value_counts()
# Out:
# airline
# UA    149
# F9     54
# NK     50
# DL     24
# AA     22
# AM     10
# B6      9
# AS      6
# Y4      4
# VB      4
# G4      1
# ZZ      1
# LH      1
# Name: count, dtype: int64

# %%
# Printing every airline to write their full name
airline_array = df['airline'].unique()
for airline in airline_array:
    print(f'* {airline}:')
# Out:
# * NK:
# * F9:
# * AA:
# * G4:
# * UA:
# * Y4:
# * VB:
# * B6:
# * DL:
# * AM:
# * AS:
# * ZZ:
# * LH:

# %% [markdown]
# Airlines
# * NK: Spirit Airlines
# * F9: Frontier Airlines
# * AA: American Airlines
# * G4: Allegiant
# * UA: United Airlines
# * Y4: Volaris
# * VB: Aeroenlace
# * B6: JetBlue
# * DL: Delta Airlines
# * AM: Aeromexico
# * AS: Alaska Airlines
# * ZZ: N/A
# * LH: Desutsche Lufthansa

# %%
# Printing every aiport to wrtie their city names
airport_array = df['destination'].unique()
for airport in airport_array:
    print(f'* {airport}: ')
# Out:
# * LAX:
# * LAS:
# * BWI:
# * ABI:
# * FLL:
# * CHI:
# * ORL:
# * ATL:
# * AVL:
# * RDU:
# * BOS:
# * DTT:
# * TPA:
# * DEN:
# * PDX:
# * HNL:
# * MYR:
# * MEX:
# * DFW:
# * SAN:
# * CAE:
# * MTY:
# * SDF:
# * ONT:
# * SEA:
# * SFO:
# * PHX:
# * DUB:
# * MSY:
# * PHL:
# * GDL:
# * BNA:
# * BIL:
# * BZE:
# * LCH:
# * NYC:
# * PVR:
# * COS:
# * PTY:
# * SAL:
# * SLU:
# * HAV:
# * MKC:
# * CUN:
# * SGN:
# * MLB:
# * GGT:
# * SJU:
# * SBN:
# * CVN:
# * QHO:
# * VCE:
# * FAO:
# * SJD:
# * FSD:
# * ANC:
# * BTR:
# * JTR:
# * REK:
# * TYO:
# * BKK:
# * YYC:
# * ATH:

# %% [markdown]
# Destinations
# * LAX: Los Angeles, California
# * LAS: Las Vegas, Nevada
# * BWI: Baltimore, Maryland
# * ABI: Abilene, Texas
# * FLL: Fort Lauderdale, Florida
# * CHI: Chicago, Illinois
# * ORL: Orlando, Florida
# * ATL: Atlanta, Georgia
# * AVL: Asheville, North Carolina
# * RDU: Morrisville, North Carolina
# * BOS: Boston, Massachusetts
# * DTT: Detroit, Michigan
# * TPA: Tampa, Florida
# * DEN: Denver, Colorado
# * PDX: Portland, Oregon
# * HNL: Honolulu, Hawaii
# * MYR: Myrtle Beach, South Carolina
# * MEX: Mexico City, Mexico
# * DFW: Dallas Fort Worth, Texas
# * SAN: San Diego, California
# * CAE: Columbia, South Carolina
# * MTY: Monterrey, Mexico
# * SDF: Louisville, Kentucky
# * ONT: Ontario, California
# * SEA: Seattle, Washington
# * SFO: San Francisco, California
# * PHX: Phoenix, Arizona
# * DUB: Dublin, Ireland
# * MSY: New Orleans, Louisiana
# * PHL: Philadelphia, Pennsylvania
# * GDL: Guadalajara, Mexico
# * BNA: Nashville, Tennessee
# * BIL: Billings, Montana
# * BZE: Belize City, Belize
# * LCH: Lake Charles, Louisiana
# * NYC: New York City, New York
# * PVR: Puerto Vallarta, Mexico
# * COS: Colorado Springs, Colorado
# * PTY: Panama City, Panama
# * SAL: San Salvador, EL Salvador
# * SLU: Castries, Saint Lucia
# * HAV: Havana, Cuba
# * MKC: Kansas City, Missouri
# * CUN: Cancun, Mexico
# * SGN: Tan Son Nhat, Vietnam
# * MLB: Melbourne, Florida
# * GGT: Exuma, The Bahamas
# * SJU: Carolina, Puerto Rico
# * SBN: South Bend, Indiana
# * CVN: Clovis, New Mexico
# * QHO: Houston, Texas
# * VCE: Venice, Italy
# * FAO: Faro, Portugal
# * SJD: San Jose del Cabo, Mexico
# * FSD: Sioux Falls, South Dakota
# * ANC: Anchorage, Alaska
# * BTR: Baton Rouge, Louisiana
# * JTR: Santorini, Greece
# * REK: Reykjavik, Iceland
# * TYO: Tokyo, Japan
# * BKK: Suvarnabhumi, Thailand
# * YYC: Calgary, Canada
# * ATH: Athens, Greece

# %%
df.loc[df['city'] == 'New York City, New York']
# Out:
#     origin destination  price airline  flight_number
# 121    SAT         NYC    299      AA            671  \
# 131    SAT         NYC    202      UA           1741
# 132    SAT         NYC    186      UA           1715
# 153    SAT         NYC    296      UA           1347
# 155    SAT         NYC    360      UA           1347
# 156    SAT         NYC    324      B6           1826
# 157    SAT         NYC    260      UA           2250
# 160    SAT         NYC    357      UA           1347
# 161    SAT         NYC    326      B6           1826
# 162    SAT         NYC    286      AA           1957
# 168    SAT         NYC    192      UA           2010
# 169    SAT         NYC    192      UA           2010
# 172    SAT         NYC    217      UA           2010
# 173    SAT         NYC    217      B6           1826
# 175    SAT         NYC    217      UA           2010
# 176    SAT         NYC    217      UA           2010
# 179    SAT         NYC    217      UA           2010
# ...
