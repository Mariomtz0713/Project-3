# %% [markdown]
# ## The beginning of a New Vacation

# %% [markdown]
# Importing the dataset with database name of sa_vacations and collection name of flights:
#
# mongoimport --type json -d sa_vacations -c flights --drop --jsonArray clean_data.json

# %%
import pandas as pd
from pymongo import MongoClient
import json
from pprint import pprint
from api_key import API_KEY

# Travel site
url = 'https://api.travelpayouts.com/v1/prices/calendar?currency=usd&origin=SAT&calendar_type=departure_date&token=' + API_KEY

# %%
# Working out example, creating list
myList = {
    'Alice': {
        'phone': '2341',
        'addr': '87 Eastlake Court'
        },

    'Beth': {
        'phone': '9102',
        'addr': '563 Hartford Drive'
        },

    'Randy': {
        'phone': '4563',
        'addr': '93 SW 43rd'
        }
}

# %%
# Working out example, appending key to inner dictionary
for person in myList:
    myList[person]['date'] = person

myList
# Out:
# {'Alice': {'phone': '2341', 'addr': '87 Eastlake Court', 'date': 'Alice'},
#  'Beth': {'phone': '9102', 'addr': '563 Hartford Drive', 'date': 'Beth'},
#  'Randy': {'phone': '4563', 'addr': '93 SW 43rd', 'date': 'Randy'}}

# %%
# Working out example, extracting inner dictionaries
newList = [myList[person] for person in myList]
newList
# Out:
# [{'phone': '2341', 'addr': '87 Eastlake Court', 'date': 'Alice'},
#  {'phone': '9102', 'addr': '563 Hartford Drive', 'date': 'Beth'},
#  {'phone': '4563', 'addr': '93 SW 43rd', 'date': 'Randy'}]

# %%
# Reading json file
with open('Resources/data.json', 'r') as openfile:
    flights = json.load(openfile)

pprint(flights)
# Out:
# {'2023-07-20': {'airline': 'NK',
#                 'departure_at': '2023-07-20T22:28:00-05:00',
#                 'destination': 'LAX',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1044,
#                 'origin': 'SAT',
#                 'price': 280,
#                 'return_at': '2023-08-01T07:15:00-07:00',
#                 'transfers': 0},
#  '2023-07-21': {'airline': 'F9',
#                 'departure_at': '2023-07-21T22:11:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 126,
#                 'return_at': '2023-07-28T16:26:00-07:00',
#                 'transfers': 0},
#  '2023-07-22': {'airline': 'NK',
#                 'departure_at': '2023-07-22T16:00:00-05:00',
#                 'destination': 'BWI',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1739,
#                 'origin': 'SAT',
#                 'price': 150,
#                 'return_at': '2023-08-05T21:19:00-04:00',
#                 'transfers': 0},
#  '2023-07-23': {'airline': 'F9',
#                 'departure_at': '2023-07-23T22:23:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 115,
#                 'return_at': '2023-07-28T16:26:00-07:00',
#                 'transfers': 0},
#  '2023-07-24': {'airline': 'F9',
#                 'departure_at': '2023-07-24T21:07:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 170,
#                 'return_at': '2023-07-28T09:20:00-07:00',
#                 'transfers': 0},
#  '2023-07-25': {'airline': 'AA',
#                 'departure_at': '2023-07-25T05:14:00-05:00',
#                 'destination': 'ABI',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2342,
#                 'origin': 'SAT',
#                 'price': 260,
#                 'return_at': '2023-08-01T06:30:00-05:00',
#                 'transfers': 1},
#  '2023-07-26': {'airline': 'NK',
#                 'departure_at': '2023-07-26T07:00:00-05:00',
#                 'destination': 'FLL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1737,
#                 'origin': 'SAT',
#                 'price': 128,
#                 'return_at': '2023-08-02T13:30:00-04:00',
#                 'transfers': 0},
#  '2023-07-27': {'airline': 'F9',
#                 'departure_at': '2023-07-27T10:28:00-05:00',
#                 'destination': 'CHI',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 991,
#                 'origin': 'SAT',
#                 'price': 158,
#                 'return_at': '2023-07-29T22:51:00-05:00',
#                 'transfers': 1},
#  '2023-07-28': {'airline': 'NK',
#                 'departure_at': '2023-07-28T07:00:00-05:00',
#                 'destination': 'FLL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1737,
#                 'origin': 'SAT',
#                 'price': 170,
#                 'return_at': '2023-08-07T13:00:00-04:00',
#                 'transfers': 0},
#  '2023-07-29': {'airline': 'F9',
#                 'departure_at': '2023-07-29T13:39:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1198,
#                 'origin': 'SAT',
#                 'price': 165,
#                 'return_at': '2023-07-30T07:15:00-04:00',
#                 'transfers': 0},
#  '2023-07-30': {'airline': 'F9',
#                 'departure_at': '2023-07-30T22:23:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 160,
#                 'return_at': '2023-08-03T09:20:00-07:00',
#                 'transfers': 0},
#  '2023-07-31': {'airline': 'G4',
#                 'departure_at': '2023-07-31T21:53:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 131,
#                 'origin': 'SAT',
#                 'price': 144,
#                 'return_at': '2023-08-03T09:20:00-07:00',
#                 'transfers': 0},
#  '2023-08-01': {'airline': 'F9',
#                 'departure_at': '2023-08-01T17:47:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1518,
#                 'origin': 'SAT',
#                 'price': 141,
#                 'return_at': '2023-08-12T09:05:00-07:00',
#                 'transfers': 1},
#  '2023-08-02': {'airline': 'NK',
#                 'departure_at': '2023-08-02T14:50:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1039,
#                 'origin': 'SAT',
#                 'price': 155,
#                 'return_at': '2023-08-02T19:40:00-07:00',
#                 'transfers': 1},
#  '2023-08-03': {'airline': 'NK',
#                 'departure_at': '2023-08-03T22:28:00-05:00',
#                 'destination': 'LAX',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1044,
#                 'origin': 'SAT',
#                 'price': 124,
#                 'return_at': '2023-08-05T14:15:00-07:00',
#                 'transfers': 0},
#  '2023-08-04': {'airline': 'F9',
#                 'departure_at': '2023-08-04T08:58:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1198,
#                 'origin': 'SAT',
#                 'price': 115,
#                 'return_at': '2023-08-07T05:35:00-04:00',
#                 'transfers': 0},
#  '2023-08-05': {'airline': 'NK',
#                 'departure_at': '2023-08-05T07:00:00-05:00',
#                 'destination': 'FLL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1737,
#                 'origin': 'SAT',
#                 'price': 119,
#                 'return_at': '2023-08-07T13:00:00-04:00',
#                 'transfers': 0},
#  '2023-08-06': {'airline': 'NK',
#                 'departure_at': '2023-08-06T16:00:00-05:00',
#                 'destination': 'BWI',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1739,
#                 'origin': 'SAT',
#                 'price': 142,
#                 'return_at': '2023-08-12T10:16:00-04:00',
#                 'transfers': 1},
#  '2023-08-07': {'airline': 'NK',
#                 'departure_at': '2023-08-07T16:00:00-05:00',
#                 'destination': 'BWI',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1739,
#                 'origin': 'SAT',
#                 'price': 92,
#                 'return_at': '2023-08-11T21:24:00-04:00',
#                 'transfers': 0},
#  '2023-08-08': {'airline': 'F9',
#                 'departure_at': '2023-08-08T17:42:00-05:00',
#                 'destination': 'ATL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1518,
#                 'origin': 'SAT',
#                 'price': 75,
#                 'return_at': '2023-08-15T15:23:00-04:00',
#                 'transfers': 0},
#  '2023-08-09': {'airline': 'NK',
#                 'departure_at': '2023-08-09T14:51:00-05:00',
#                 'destination': 'LAX',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1039,
#                 'origin': 'SAT',
#                 'price': 159,
#                 'return_at': '2023-08-12T15:07:00-07:00',
#                 'transfers': 1},
#  '2023-08-10': {'airline': 'NK',
#                 'departure_at': '2023-08-10T16:07:00-05:00',
#                 'destination': 'BWI',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1739,
#                 'origin': 'SAT',
#                 'price': 78,
#                 'return_at': '2023-08-13T21:24:00-04:00',
#                 'transfers': 0},
#  '2023-08-11': {'airline': 'NK',
#                 'departure_at': '2023-08-11T07:00:00-05:00',
#                 'destination': 'FLL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1737,
#                 'origin': 'SAT',
#                 'price': 109,
#                 'return_at': '2023-08-16T16:59:00-04:00',
#                 'transfers': 0},
#  '2023-08-12': {'airline': 'NK',
#                 'departure_at': '2023-08-12T14:51:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1039,
#                 'origin': 'SAT',
#                 'price': 147,
#                 'return_at': '2023-08-15T09:05:00-07:00',
#                 'transfers': 0},
#  '2023-08-13': {'airline': 'NK',
#                 'departure_at': '2023-08-13T07:00:00-05:00',
#                 'destination': 'AVL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1737,
#                 'origin': 'SAT',
#                 'price': 232,
#                 'return_at': '2023-08-18T14:23:00-04:00',
#                 'transfers': 1},
#  '2023-08-14': {'airline': 'NK',
#                 'departure_at': '2023-08-14T07:00:00-05:00',
#                 'destination': 'FLL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1737,
#                 'origin': 'SAT',
#                 'price': 120,
#                 'return_at': '2023-08-21T13:05:00-04:00',
#                 'transfers': 0},
#  '2023-08-15': {'airline': 'F9',
#                 'departure_at': '2023-08-15T20:07:00-05:00',
#                 'destination': 'RDU',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 555,
#                 'origin': 'SAT',
#                 'price': 132,
#                 'return_at': '2023-08-19T05:45:00-04:00',
#                 'transfers': 1},
#  '2023-08-16': {'airline': 'F9',
#                 'departure_at': '2023-08-16T19:41:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 155,
#                 'return_at': '2023-08-20T09:05:00-07:00',
#                 'transfers': 0},
#  '2023-08-17': {'airline': 'F9',
#                 'departure_at': '2023-08-17T19:08:00-05:00',
#                 'destination': 'ATL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1518,
#                 'origin': 'SAT',
#                 'price': 93,
#                 'return_at': '2023-08-24T16:43:00-04:00',
#                 'transfers': 0},
#  '2023-08-18': {'airline': 'F9',
#                 'departure_at': '2023-08-18T10:08:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1198,
#                 'origin': 'SAT',
#                 'price': 104,
#                 'return_at': '2023-08-24T08:20:00-04:00',
#                 'transfers': 0},
#  '2023-08-19': {'airline': 'NK',
#                 'departure_at': '2023-08-19T07:00:00-05:00',
#                 'destination': 'BOS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1737,
#                 'origin': 'SAT',
#                 'price': 160,
#                 'return_at': '2023-08-23T06:00:00-04:00',
#                 'transfers': 1},
#  '2023-08-20': {'airline': 'F9',
#                 'departure_at': '2023-08-20T20:17:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 137,
#                 'return_at': '2023-08-25T15:53:00-07:00',
#                 'transfers': 0},
#  '2023-08-21': {'airline': 'F9',
#                 'departure_at': '2023-08-21T16:59:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1198,
#                 'origin': 'SAT',
#                 'price': 101,
#                 'return_at': '2023-08-25T07:20:00-04:00',
#                 'transfers': 0},
#  '2023-08-22': {'airline': 'F9',
#                 'departure_at': '2023-08-22T21:38:00-05:00',
#                 'destination': 'DTT',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 991,
#                 'origin': 'SAT',
#                 'price': 168,
#                 'return_at': '2023-08-29T13:35:00-04:00',
#                 'transfers': 1},
#  '2023-08-23': {'airline': 'NK',
#                 'departure_at': '2023-08-23T07:00:00-05:00',
#                 'destination': 'TPA',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1737,
#                 'origin': 'SAT',
#                 'price': 127,
#                 'return_at': '2023-08-28T10:13:00-04:00',
#                 'transfers': 1},
#  '2023-08-24': {'airline': 'F9',
#                 'departure_at': '2023-08-24T23:01:00-05:00',
#                 'destination': 'DEN',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 991,
#                 'origin': 'SAT',
#                 'price': 90,
#                 'return_at': '2023-08-31T18:55:00-06:00',
#                 'transfers': 0},
#  '2023-08-25': {'airline': 'F9',
#                 'departure_at': '2023-08-25T10:01:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1198,
#                 'origin': 'SAT',
#                 'price': 128,
#                 'return_at': '2023-08-28T14:04:00-04:00',
#                 'transfers': 0},
#  '2023-08-26': {'airline': 'UA',
#                 'departure_at': '2023-08-26T16:24:00-05:00',
#                 'destination': 'PDX',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1373,
#                 'origin': 'SAT',
#                 'price': 262,
#                 'return_at': '2023-09-02T07:12:00-07:00',
#                 'transfers': 1},
#  '2023-08-27': {'airline': 'UA',
#                 'departure_at': '2023-08-27T05:15:00-05:00',
#                 'destination': 'HNL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 469,
#                 'origin': 'SAT',
#                 'price': 358,
#                 'return_at': '2023-08-30T19:55:00-10:00',
#                 'transfers': 1},
#  '2023-08-28': {'airline': 'NK',
#                 'departure_at': '2023-08-28T20:59:00-05:00',
#                 'destination': 'LAX',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1044,
#                 'origin': 'SAT',
#                 'price': 162,
#                 'return_at': '2023-08-29T12:44:00-07:00',
#                 'transfers': 1},
#  '2023-08-29': {'airline': 'NK',
#                 'departure_at': '2023-08-29T07:00:00-05:00',
#                 'destination': 'MYR',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1737,
#                 'origin': 'SAT',
#                 'price': 200,
#                 'return_at': '2023-08-31T10:25:00-04:00',
#                 'transfers': 1},
#  '2023-08-30': {'airline': 'Y4',
#                 'departure_at': '2023-08-30T13:35:00-05:00',
#                 'destination': 'MEX',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 837,
#                 'origin': 'SAT',
#                 'price': 216,
#                 'return_at': '2023-09-02T12:20:00-05:00',
#                 'transfers': 1},
#  '2023-08-31': {'airline': 'UA',
#                 'departure_at': '2023-08-31T05:15:00-05:00',
#                 'destination': 'DFW',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 469,
#                 'origin': 'SAT',
#                 'price': 188,
#                 'return_at': '2023-09-02T17:48:00-05:00',
#                 'transfers': 1},
#  '2023-09-01': {'airline': 'F9',
#                 'departure_at': '2023-09-01T10:01:00-05:00',
#                 'destination': 'ATL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1198,
#                 'origin': 'SAT',
#                 'price': 189,
#                 'return_at': '2023-09-05T08:05:00-04:00',
#                 'transfers': 1},
#  '2023-09-02': {'airline': 'F9',
#                 'departure_at': '2023-09-02T12:09:00-05:00',
#                 'destination': 'BWI',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1198,
#                 'origin': 'SAT',
#                 'price': 128,
#                 'return_at': '2023-09-04T21:24:00-04:00',
#                 'transfers': 1},
#  '2023-09-03': {'airline': 'Y4',
#                 'departure_at': '2023-09-03T13:35:00-05:00',
#                 'destination': 'MEX',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 837,
#                 'origin': 'SAT',
#                 'price': 214,
#                 'return_at': '2023-09-10T12:20:00-05:00',
#                 'transfers': 1},
#  '2023-09-04': {'airline': 'F9',
#                 'departure_at': '2023-09-04T21:34:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 116,
#                 'return_at': '2023-09-07T06:00:00-07:00',
#                 'transfers': 0},
#  '2023-09-05': {'airline': 'F9',
#                 'departure_at': '2023-09-05T21:38:00-05:00',
#                 'destination': 'DEN',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 991,
#                 'origin': 'SAT',
#                 'price': 87,
#                 'return_at': '2023-09-12T17:41:00-06:00',
#                 'transfers': 0},
#  '2023-09-06': {'airline': 'F9',
#                 'departure_at': '2023-09-06T21:41:00-05:00',
#                 'destination': 'SAN',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 167,
#                 'return_at': '2023-09-20T08:27:00-07:00',
#                 'transfers': 1},
#  '2023-09-07': {'airline': 'F9',
#                 'departure_at': '2023-09-07T18:27:00-05:00',
#                 'destination': 'CHI',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1518,
#                 'origin': 'SAT',
#                 'price': 180,
#                 'return_at': '2023-09-11T13:03:00-05:00',
#                 'transfers': 1},
#  '2023-09-08': {'airline': 'F9',
#                 'departure_at': '2023-09-08T12:10:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2103,
#                 'origin': 'SAT',
#                 'price': 116,
#                 'return_at': '2023-09-13T16:00:00-07:00',
#                 'transfers': 0},
#  '2023-09-09': {'airline': 'F9',
#                 'departure_at': '2023-09-09T12:00:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 89,
#                 'return_at': '2023-09-13T16:00:00-07:00',
#                 'transfers': 0},
#  '2023-09-10': {'airline': 'F9',
#                 'departure_at': '2023-09-10T22:36:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 117,
#                 'return_at': '2023-09-13T16:00:00-07:00',
#                 'transfers': 0},
#  '2023-09-11': {'airline': 'AA',
#                 'departure_at': '2023-09-11T06:15:00-05:00',
#                 'destination': 'CAE',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2556,
#                 'origin': 'SAT',
#                 'price': 390,
#                 'return_at': '2023-09-13T16:19:00-04:00',
#                 'transfers': 1},
#  '2023-09-12': {'airline': 'VB',
#                 'departure_at': '2023-09-12T21:00:00-05:00',
#                 'destination': 'MTY',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 677,
#                 'origin': 'SAT',
#                 'price': 208,
#                 'return_at': '2023-09-18T08:25:00-05:00',
#                 'transfers': 0},
#  '2023-09-13': {'airline': 'NK',
#                 'departure_at': '2023-09-13T14:31:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1039,
#                 'origin': 'SAT',
#                 'price': 100,
#                 'return_at': '2023-09-19T09:00:00-07:00',
#                 'transfers': 0},
#  '2023-09-14': {'airline': 'F9',
#                 'departure_at': '2023-09-14T19:46:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1200,
#                 'origin': 'SAT',
#                 'price': 130,
#                 'return_at': '2023-09-17T17:15:00-04:00',
#                 'transfers': 0},
#  '2023-09-15': {'airline': 'F9',
#                 'departure_at': '2023-09-15T21:41:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2073,
#                 'origin': 'SAT',
#                 'price': 115,
#                 'return_at': '2023-09-17T06:10:00-07:00',
#                 'transfers': 0},
#  '2023-09-16': {'airline': 'NK',
#                 'departure_at': '2023-09-16T20:20:00-05:00',
#                 'destination': 'LAX',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1044,
#                 'origin': 'SAT',
#                 'price': 96,
#                 'return_at': '2023-09-18T13:28:00-07:00',
#                 'transfers': 0},
#  '2023-09-17': {'airline': 'AA',
#                 'departure_at': '2023-09-17T10:31:00-05:00',
#                 'destination': 'DFW',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2759,
#                 'origin': 'SAT',
#                 'price': 212,
#                 'return_at': '2023-09-18T07:08:00-05:00',
#                 'transfers': 0},
#  '2023-09-18': {'airline': 'NK',
#                 'departure_at': '2023-09-18T07:00:00-05:00',
#                 'destination': 'SDF',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1737,
#                 'origin': 'SAT',
#                 'price': 173,
#                 'return_at': '2023-09-23T11:38:00-04:00',
#                 'transfers': 1},
#  '2023-09-19': {'airline': 'F9',
#                 'departure_at': '2023-09-19T21:53:00-05:00',
#                 'destination': 'DEN',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 991,
#                 'origin': 'SAT',
#                 'price': 80,
#                 'return_at': '2023-09-24T17:24:00-06:00',
#                 'transfers': 0},
#  '2023-09-20': {'airline': 'F9',
#                 'departure_at': '2023-09-20T21:41:00-05:00',
#                 'destination': 'ONT',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 135,
#                 'return_at': '2023-09-25T13:28:00-07:00',
#                 'transfers': 1},
#  '2023-09-21': {'airline': 'F9',
#                 'departure_at': '2023-09-21T19:46:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1200,
#                 'origin': 'SAT',
#                 'price': 123,
#                 'return_at': '2023-09-24T17:15:00-04:00',
#                 'transfers': 0},
#  '2023-09-22': {'airline': 'VB',
#                 'departure_at': '2023-09-22T17:45:00-05:00',
#                 'destination': 'MEX',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 165,
#                 'origin': 'SAT',
#                 'price': 221,
#                 'return_at': '2023-10-02T12:20:00-05:00',
#                 'transfers': 1},
#  '2023-09-23': {'airline': 'NK',
#                 'departure_at': '2023-09-23T14:31:00-05:00',
#                 'destination': 'SAN',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1039,
#                 'origin': 'SAT',
#                 'price': 132,
#                 'return_at': '2023-09-26T12:51:00-07:00',
#                 'transfers': 1},
#  '2023-09-24': {'airline': 'F9',
#                 'departure_at': '2023-09-24T11:50:00-05:00',
#                 'destination': 'SEA',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2103,
#                 'origin': 'SAT',
#                 'price': 188,
#                 'return_at': '2023-09-26T21:19:00-07:00',
#                 'transfers': 1},
#  '2023-09-25': {'airline': 'NK',
#                 'departure_at': '2023-09-25T12:40:00-05:00',
#                 'destination': 'BWI',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2010,
#                 'origin': 'SAT',
#                 'price': 97,
#                 'return_at': '2023-09-29T09:03:00-04:00',
#                 'transfers': 0},
#  '2023-09-26': {'airline': 'F9',
#                 'departure_at': '2023-09-26T20:29:00-05:00',
#                 'destination': 'PDX',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 173,
#                 'return_at': '2023-09-30T19:47:00-07:00',
#                 'transfers': 1},
#  '2023-09-27': {'airline': 'NK',
#                 'departure_at': '2023-09-27T07:00:00-05:00',
#                 'destination': 'TPA',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1737,
#                 'origin': 'SAT',
#                 'price': 131,
#                 'return_at': '2023-09-30T10:10:00-04:00',
#                 'transfers': 1},
#  '2023-09-28': {'airline': 'F9',
#                 'departure_at': '2023-09-28T19:46:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1200,
#                 'origin': 'SAT',
#                 'price': 120,
#                 'return_at': '2023-09-30T08:20:00-04:00',
#                 'transfers': 0},
#  '2023-09-29': {'airline': 'NK',
#                 'departure_at': '2023-09-29T07:00:00-05:00',
#                 'destination': 'TPA',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1737,
#                 'origin': 'SAT',
#                 'price': 178,
#                 'return_at': '2023-10-01T10:10:00-04:00',
#                 'transfers': 1},
#  '2023-09-30': {'airline': 'F9',
#                 'departure_at': '2023-09-30T12:00:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 110,
#                 'return_at': '2023-10-02T16:08:00-07:00',
#                 'transfers': 0},
#  '2023-10-01': {'airline': 'AA',
#                 'departure_at': '2023-10-01T09:14:00-05:00',
#                 'destination': 'DFW',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1965,
#                 'origin': 'SAT',
#                 'price': 237,
#                 'return_at': '2023-10-08T09:30:00-05:00',
#                 'transfers': 0},
#  '2023-10-02': {'airline': 'NK',
#                 'departure_at': '2023-10-02T07:00:00-05:00',
#                 'destination': 'BOS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1737,
#                 'origin': 'SAT',
#                 'price': 208,
#                 'return_at': '2023-10-05T08:00:00-04:00',
#                 'transfers': 1},
#  '2023-10-03': {'airline': 'NK',
#                 'departure_at': '2023-10-03T07:00:00-05:00',
#                 'destination': 'CHI',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1737,
#                 'origin': 'SAT',
#                 'price': 232,
#                 'return_at': '2023-10-05T10:45:00-05:00',
#                 'transfers': 2},
#  '2023-10-04': {'airline': 'UA',
#                 'departure_at': '2023-10-04T05:45:00-05:00',
#                 'destination': 'SFO',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2663,
#                 'origin': 'SAT',
#                 'price': 222,
#                 'return_at': '2023-10-04T23:50:00-07:00',
#                 'transfers': 1},
#  '2023-10-05': {'airline': 'AA',
#                 'departure_at': '2023-10-05T19:01:00-05:00',
#                 'destination': 'SEA',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 614,
#                 'origin': 'SAT',
#                 'price': 216,
#                 'return_at': '2023-10-08T05:19:00-07:00',
#                 'transfers': 1},
#  '2023-10-06': {'airline': 'F9',
#                 'departure_at': '2023-10-06T10:54:00-05:00',
#                 'destination': 'PHX',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1198,
#                 'origin': 'SAT',
#                 'price': 248,
#                 'return_at': '2023-10-16T21:22:00-07:00',
#                 'transfers': 1},
#  '2023-10-07': {'airline': 'F9',
#                 'departure_at': '2023-10-07T19:59:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 234,
#                 'return_at': '2023-10-10T14:34:00-07:00',
#                 'transfers': 0},
#  '2023-10-08': {'airline': 'AA',
#                 'departure_at': '2023-10-08T05:00:00-05:00',
#                 'destination': 'SEA',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2397,
#                 'origin': 'SAT',
#                 'price': 311,
#                 'return_at': '2023-10-08T23:56:00-07:00',
#                 'transfers': 1},
#  '2023-10-09': {'airline': 'F9',
#                 'departure_at': '2023-10-09T10:54:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1198,
#                 'origin': 'SAT',
#                 'price': 142,
#                 'return_at': '2023-10-16T08:00:00-04:00',
#                 'transfers': 0},
#  '2023-10-10': {'airline': 'UA',
#                 'departure_at': '2023-10-10T09:44:00-05:00',
#                 'destination': 'DUB',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2460,
#                 'origin': 'SAT',
#                 'price': 642,
#                 'return_at': '2023-10-24T12:15:00+01:00',
#                 'transfers': 2},
#  '2023-10-11': {'airline': 'B6',
#                 'departure_at': '2023-10-11T14:30:00-05:00',
#                 'destination': 'BOS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1826,
#                 'origin': 'SAT',
#                 'price': 218,
#                 'return_at': '2023-10-18T07:55:00-04:00',
#                 'transfers': 1},
#  '2023-10-12': {'airline': 'UA',
#                 'departure_at': '2023-10-12T05:21:00-05:00',
#                 'destination': 'MSY',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 469,
#                 'origin': 'SAT',
#                 'price': 171,
#                 'return_at': '2023-10-15T05:00:00-05:00',
#                 'transfers': 1},
#  '2023-10-13': {'airline': 'NK',
#                 'departure_at': '2023-10-13T19:16:00-05:00',
#                 'destination': 'LAX',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1044,
#                 'origin': 'SAT',
#                 'price': 152,
#                 'return_at': '2023-10-20T13:28:00-07:00',
#                 'transfers': 0},
#  '2023-10-14': {'airline': 'F9',
#                 'departure_at': '2023-10-14T15:02:00-05:00',
#                 'destination': 'PHL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 991,
#                 'origin': 'SAT',
#                 'price': 181,
#                 'return_at': '2023-10-16T15:15:00-04:00',
#                 'transfers': 1},
#  '2023-10-15': {'airline': 'F9',
#                 'departure_at': '2023-10-15T15:02:00-05:00',
#                 'destination': 'CHI',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 991,
#                 'origin': 'SAT',
#                 'price': 186,
#                 'return_at': '2023-10-16T22:24:00-05:00',
#                 'transfers': 1},
#  '2023-10-16': {'airline': 'F9',
#                 'departure_at': '2023-10-16T10:54:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1198,
#                 'origin': 'SAT',
#                 'price': 126,
#                 'return_at': '2023-10-21T08:00:00-04:00',
#                 'transfers': 0},
#  '2023-10-17': {'airline': 'F9',
#                 'departure_at': '2023-10-17T15:02:00-05:00',
#                 'destination': 'DEN',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 991,
#                 'origin': 'SAT',
#                 'price': 87,
#                 'return_at': '2023-10-21T11:00:00-06:00',
#                 'transfers': 0},
#  '2023-10-18': {'airline': 'F9',
#                 'departure_at': '2023-10-18T19:59:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 117,
#                 'return_at': '2023-10-21T14:34:00-07:00',
#                 'transfers': 0},
#  '2023-10-19': {'airline': 'NK',
#                 'departure_at': '2023-10-19T07:00:00-05:00',
#                 'destination': 'TPA',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1737,
#                 'origin': 'SAT',
#                 'price': 164,
#                 'return_at': '2023-10-23T10:13:00-04:00',
#                 'transfers': 1},
#  '2023-10-20': {'airline': 'NK',
#                 'departure_at': '2023-10-20T19:16:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1044,
#                 'origin': 'SAT',
#                 'price': 297,
#                 'return_at': '2023-10-22T05:46:00-07:00',
#                 'transfers': 1},
#  '2023-10-21': {'airline': 'NK',
#                 'departure_at': '2023-10-21T20:13:00-05:00',
#                 'destination': 'LAX',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1044,
#                 'origin': 'SAT',
#                 'price': 132,
#                 'return_at': '2023-10-23T13:28:00-07:00',
#                 'transfers': 0},
#  '2023-10-22': {'airline': 'F9',
#                 'departure_at': '2023-10-22T21:09:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 154,
#                 'return_at': '2023-10-26T14:34:00-07:00',
#                 'transfers': 0},
#  '2023-10-23': {'airline': 'NK',
#                 'departure_at': '2023-10-23T11:10:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1718,
#                 'origin': 'SAT',
#                 'price': 146,
#                 'return_at': '2023-10-27T08:20:00-04:00',
#                 'transfers': 0},
#  '2023-10-24': {'airline': 'VB',
#                 'departure_at': '2023-10-24T20:55:00-05:00',
#                 'destination': 'GDL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 677,
#                 'origin': 'SAT',
#                 'price': 270,
#                 'return_at': '2023-10-27T07:00:00-05:00',
#                 'transfers': 1},
#  '2023-10-25': {'airline': 'F9',
#                 'departure_at': '2023-10-25T10:54:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1198,
#                 'origin': 'SAT',
#                 'price': 127,
#                 'return_at': '2023-10-30T08:00:00-04:00',
#                 'transfers': 0},
#  '2023-10-26': {'airline': 'NK',
#                 'departure_at': '2023-10-26T07:00:00-05:00',
#                 'destination': 'BNA',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1737,
#                 'origin': 'SAT',
#                 'price': 215,
#                 'return_at': '2023-10-31T06:10:00-05:00',
#                 'transfers': 1},
#  '2023-10-27': {'airline': 'F9',
#                 'departure_at': '2023-10-27T10:54:00-05:00',
#                 'destination': 'ATL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1198,
#                 'origin': 'SAT',
#                 'price': 205,
#                 'return_at': '2023-10-29T22:44:00-04:00',
#                 'transfers': 1},
#  '2023-10-28': {'airline': 'UA',
#                 'departure_at': '2023-10-28T12:55:00-05:00',
#                 'destination': 'BOS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1715,
#                 'origin': 'SAT',
#                 'price': 193,
#                 'return_at': '2023-11-02T09:00:00-04:00',
#                 'transfers': 1},
#  '2023-10-29': {'airline': 'AA',
#                 'departure_at': '2023-10-29T05:00:00-05:00',
#                 'destination': 'BOS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2616,
#                 'origin': 'SAT',
#                 'price': 189,
#                 'return_at': '2023-11-01T18:14:00-04:00',
#                 'transfers': 1},
#  '2023-10-30': {'airline': 'AA',
#                 'departure_at': '2023-10-30T18:00:00-05:00',
#                 'destination': 'BOS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2380,
#                 'origin': 'SAT',
#                 'price': 194,
#                 'return_at': '2023-11-03T18:14:00-04:00',
#                 'transfers': 1},
#  '2023-10-31': {'airline': 'F9',
#                 'departure_at': '2023-10-31T19:59:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 122,
#                 'return_at': '2023-11-03T14:34:00-07:00',
#                 'transfers': 0},
#  '2023-11-01': {'airline': 'UA',
#                 'departure_at': '2023-11-01T07:00:00-05:00',
#                 'destination': 'HNL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1894,
#                 'origin': 'SAT',
#                 'price': 461,
#                 'return_at': '2023-11-08T08:00:00-10:00',
#                 'transfers': 2},
#  '2023-11-02': {'airline': 'UA',
#                 'departure_at': '2023-11-02T08:46:00-05:00',
#                 'destination': 'BIL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1654,
#                 'origin': 'SAT',
#                 'price': 336,
#                 'return_at': '2023-11-05T06:00:00-07:00',
#                 'transfers': 1},
#  '2023-11-03': {'airline': 'NK',
#                 'departure_at': '2023-11-03T14:31:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1039,
#                 'origin': 'SAT',
#                 'price': 245,
#                 'return_at': '2023-11-05T04:46:00-08:00',
#                 'transfers': 1},
#  '2023-11-04': {'airline': 'F9',
#                 'departure_at': '2023-11-04T19:59:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 107,
#                 'return_at': '2023-11-08T14:34:00-08:00',
#                 'transfers': 0},
#  '2023-11-05': {'airline': 'NK',
#                 'departure_at': '2023-11-05T11:10:00-06:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1718,
#                 'origin': 'SAT',
#                 'price': 131,
#                 'return_at': '2023-11-11T08:20:00-05:00',
#                 'transfers': 0},
#  '2023-11-06': {'airline': 'F9',
#                 'departure_at': '2023-11-06T19:59:00-06:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 162,
#                 'return_at': '2023-11-10T09:00:00-08:00',
#                 'transfers': 0},
#  '2023-11-07': {'airline': 'F9',
#                 'departure_at': '2023-11-07T19:59:00-06:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 115,
#                 'return_at': '2023-11-09T14:34:00-08:00',
#                 'transfers': 0},
#  '2023-11-08': {'airline': 'F9',
#                 'departure_at': '2023-11-08T10:54:00-06:00',
#                 'destination': 'DEN',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1198,
#                 'origin': 'SAT',
#                 'price': 126,
#                 'return_at': '2023-11-14T11:00:00-07:00',
#                 'transfers': 1},
#  '2023-11-09': {'airline': 'UA',
#                 'departure_at': '2023-11-09T19:39:00-06:00',
#                 'destination': 'BZE',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 6343,
#                 'origin': 'SAT',
#                 'price': 482,
#                 'return_at': '2023-11-14T13:45:00-06:00',
#                 'transfers': 1},
#  '2023-11-10': {'airline': 'NK',
#                 'departure_at': '2023-11-10T14:31:00-06:00',
#                 'destination': 'SAN',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1039,
#                 'origin': 'SAT',
#                 'price': 282,
#                 'return_at': '2023-11-12T19:05:00-08:00',
#                 'transfers': 1},
#  '2023-11-11': {'airline': 'F9',
#                 'departure_at': '2023-11-11T19:59:00-06:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 95,
#                 'return_at': '2023-11-15T14:34:00-08:00',
#                 'transfers': 0},
#  '2023-11-12': {'airline': 'AA',
#                 'departure_at': '2023-11-12T05:00:00-06:00',
#                 'destination': 'SEA',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2616,
#                 'origin': 'SAT',
#                 'price': 316,
#                 'return_at': '2023-11-16T12:30:00-08:00',
#                 'transfers': 1},
#  '2023-11-13': {'airline': 'UA',
#                 'departure_at': '2023-11-13T16:17:00-06:00',
#                 'destination': 'SEA',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 680,
#                 'origin': 'SAT',
#                 'price': 313,
#                 'return_at': '2023-11-17T07:00:00-08:00',
#                 'transfers': 1},
#  '2023-11-14': {'airline': 'F9',
#                 'departure_at': '2023-11-14T19:59:00-06:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2075,
#                 'origin': 'SAT',
#                 'price': 312,
#                 'return_at': '2023-11-20T17:33:00-05:00',
#                 'transfers': 1},
#  '2023-11-15': {'airline': 'AA',
#                 'departure_at': '2023-11-15T07:00:00-06:00',
#                 'destination': 'HNL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 6338,
#                 'origin': 'SAT',
#                 'price': 1133,
#                 'return_at': '2023-11-25T08:00:00-10:00',
#                 'transfers': 1},
#  '2023-11-16': {'airline': 'UA',
#                 'departure_at': '2023-11-16T07:15:00-06:00',
#                 'destination': 'LCH',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1491,
#                 'origin': 'SAT',
#                 'price': 306,
#                 'return_at': '2023-11-20T11:55:00-06:00',
#                 'transfers': 1},
#  '2023-11-17': {'airline': 'UA',
#                 'departure_at': '2023-11-17T16:17:00-06:00',
#                 'destination': 'DEN',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 680,
#                 'origin': 'SAT',
#                 'price': 352,
#                 'return_at': '2023-11-24T20:51:00-07:00',
#                 'transfers': 0},
#  '2023-11-18': {'airline': 'AA',
#                 'departure_at': '2023-11-18T06:29:00-06:00',
#                 'destination': 'NYC',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 671,
#                 'origin': 'SAT',
#                 'price': 299,
#                 'return_at': '2023-11-29T16:00:00-05:00',
#                 'transfers': 1},
#  '2023-11-19': {'airline': 'Y4',
#                 'departure_at': '2023-11-19T10:20:00-06:00',
#                 'destination': 'PVR',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 837,
#                 'origin': 'SAT',
#                 'price': 330,
#                 'return_at': '2023-11-24T22:10:00-06:00',
#                 'transfers': 1},
#  '2023-11-20': {'airline': 'UA',
#                 'departure_at': '2023-11-20T16:17:00-06:00',
#                 'destination': 'BIL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 680,
#                 'origin': 'SAT',
#                 'price': 416,
#                 'return_at': '2023-11-27T18:05:00-07:00',
#                 'transfers': 1},
#  '2023-11-21': {'airline': 'UA',
#                 'departure_at': '2023-11-21T05:25:00-06:00',
#                 'destination': 'COS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2663,
#                 'origin': 'SAT',
#                 'price': 208,
#                 'return_at': '2023-11-24T15:30:00-07:00',
#                 'transfers': 1},
#  '2023-11-22': {'airline': 'NK',
#                 'departure_at': '2023-11-22T14:38:00-06:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1039,
#                 'origin': 'SAT',
#                 'price': 324,
#                 'return_at': '2023-11-26T09:05:00-08:00',
#                 'transfers': 0},
#  '2023-11-23': {'airline': 'UA',
#                 'departure_at': '2023-11-23T05:25:00-06:00',
#                 'destination': 'PDX',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2663,
#                 'origin': 'SAT',
# ...
#                 'transfers': 0},
#  '2024-05-08': {'airline': 'AS',
#                 'departure_at': '2024-05-08T18:00:00-05:00',
#                 'destination': 'ANC',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 494,
#                 'origin': 'SAT',
#                 'price': 536,
#                 'return_at': '2024-05-15T05:00:00-08:00',
#                 'transfers': 1},
#  '2024-05-09': {'airline': 'DL',
#                 'departure_at': '2024-05-09T18:20:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1465,
#                 'origin': 'SAT',
#                 'price': 376,
#                 'return_at': '2024-05-13T19:50:00-04:00',
#                 'transfers': 1},
#  '2024-05-10': {'airline': 'AS',
#                 'departure_at': '2024-05-10T07:00:00-05:00',
#                 'destination': 'SEA',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 495,
#                 'origin': 'SAT',
#                 'price': 335,
#                 'return_at': '2024-05-18T11:00:00-07:00',
#                 'transfers': 0},
#  '2024-05-11': {'airline': 'UA',
#                 'departure_at': '2024-05-11T12:24:00-05:00',
#                 'destination': 'SEA',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2498,
#                 'origin': 'SAT',
#                 'price': 358,
#                 'return_at': '2024-05-25T05:20:00-07:00',
#                 'transfers': 1},
#  '2024-05-12': {'airline': 'UA',
#                 'departure_at': '2024-05-12T05:45:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2663,
#                 'origin': 'SAT',
#                 'price': 221,
#                 'return_at': '2024-05-18T07:17:00-07:00',
#                 'transfers': 1},
#  '2024-05-13': {'airline': 'DL',
#                 'departure_at': '2024-05-13T18:25:00-05:00',
#                 'destination': 'SFO',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1422,
#                 'origin': 'SAT',
#                 'price': 336,
#                 'return_at': '2024-05-21T17:15:00-07:00',
#                 'transfers': 1},
#  '2024-05-14': {'airline': 'UA',
#                 'departure_at': '2024-05-14T07:30:00-05:00',
#                 'destination': 'NYC',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1347,
#                 'origin': 'SAT',
#                 'price': 222,
#                 'return_at': '2024-05-29T12:31:00-04:00',
#                 'transfers': 1},
#  '2024-05-15': {'airline': 'UA',
#                 'departure_at': '2024-05-15T07:30:00-05:00',
#                 'destination': 'NYC',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1347,
#                 'origin': 'SAT',
#                 'price': 267,
#                 'return_at': '2024-05-29T12:31:00-04:00',
#                 'transfers': 1},
#  '2024-05-16': {'airline': 'UA',
#                 'departure_at': '2024-05-16T07:30:00-05:00',
#                 'destination': 'NYC',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1347,
#                 'origin': 'SAT',
#                 'price': 360,
#                 'return_at': '2024-05-28T12:30:00-04:00',
#                 'transfers': 2},
#  '2024-05-17': {'airline': 'DL',
#                 'departure_at': '2024-05-17T13:40:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1408,
#                 'origin': 'SAT',
#                 'price': 306,
#                 'return_at': '2024-05-20T11:05:00-04:00',
#                 'transfers': 1},
#  '2024-05-18': {'airline': 'UA',
#                 'departure_at': '2024-05-18T05:45:00-05:00',
#                 'destination': 'HAV',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 469,
#                 'origin': 'SAT',
#                 'price': 369,
#                 'return_at': '2024-05-31T15:30:00-04:00',
#                 'transfers': 1},
#  '2024-05-19': {'airline': 'AM',
#                 'departure_at': '2024-05-19T07:55:00-05:00',
#                 'destination': 'CUN',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 631,
#                 'origin': 'SAT',
#                 'price': 431,
#                 'return_at': '2024-05-24T12:30:00-05:00',
#                 'transfers': 1},
#  '2024-05-20': {'airline': 'DL',
#                 'departure_at': '2024-05-20T18:20:00-05:00',
#                 'destination': 'NYC',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1465,
#                 'origin': 'SAT',
#                 'price': 396,
#                 'return_at': '2024-06-03T06:00:00-04:00',
#                 'transfers': 1},
#  '2024-05-21': {'airline': 'UA',
#                 'departure_at': '2024-05-21T14:15:00-05:00',
#                 'destination': 'LAX',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2496,
#                 'origin': 'SAT',
#                 'price': 394,
#                 'return_at': '2024-05-26T09:10:00-07:00',
#                 'transfers': 1},
#  '2024-05-22': {'airline': 'UA',
#                 'departure_at': '2024-05-22T05:45:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2663,
#                 'origin': 'SAT',
#                 'price': 221,
#                 'return_at': '2024-05-28T07:17:00-07:00',
#                 'transfers': 1},
#  '2024-05-23': {'airline': 'UA',
#                 'departure_at': '2024-05-23T14:15:00-05:00',
#                 'destination': 'ATL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2496,
#                 'origin': 'SAT',
#                 'price': 317,
#                 'return_at': '2024-05-28T15:45:00-04:00',
#                 'transfers': 1},
#  '2024-05-24': {'airline': 'AM',
#                 'departure_at': '2024-05-24T07:55:00-05:00',
#                 'destination': 'CUN',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 631,
#                 'origin': 'SAT',
#                 'price': 431,
#                 'return_at': '2024-05-28T13:25:00-05:00',
#                 'transfers': 1},
#  '2024-05-25': {'airline': 'UA',
#                 'departure_at': '2024-05-25T05:45:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2663,
#                 'origin': 'SAT',
#                 'price': 221,
#                 'return_at': '2024-05-31T07:17:00-07:00',
#                 'transfers': 1},
#  '2024-05-26': {'airline': 'DL',
#                 'departure_at': '2024-05-26T05:40:00-05:00',
#                 'destination': 'BTR',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1027,
#                 'origin': 'SAT',
#                 'price': 248,
#                 'return_at': '2024-06-01T06:00:00-05:00',
#                 'transfers': 1},
#  '2024-05-27': {'airline': 'UA',
#                 'departure_at': '2024-05-27T14:15:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2496,
#                 'origin': 'SAT',
#                 'price': 266,
#                 'return_at': '2024-06-01T07:05:00-04:00',
#                 'transfers': 1},
#  '2024-05-28': {'airline': 'UA',
#                 'departure_at': '2024-05-28T16:45:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 680,
#                 'origin': 'SAT',
#                 'price': 389,
#                 'return_at': '2024-05-31T07:17:00-07:00',
#                 'transfers': 1},
#  '2024-05-29': {'airline': 'AA',
#                 'departure_at': '2024-05-29T06:21:00-05:00',
#                 'destination': 'JTR',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 5571,
#                 'origin': 'SAT',
#                 'price': 1712,
#                 'return_at': '2024-06-03T19:05:00+03:00',
#                 'transfers': 2},
#  '2024-05-30': {'airline': 'UA',
#                 'departure_at': '2024-05-30T07:00:00-05:00',
#                 'destination': 'REK',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1894,
#                 'origin': 'SAT',
#                 'price': 1299,
#                 'return_at': '2024-06-13T10:00:00Z',
#                 'transfers': 2},
#  '2024-05-31': {'airline': 'UA',
#                 'departure_at': '2024-05-31T19:00:00-05:00',
#                 'destination': 'LAX',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1022,
#                 'origin': 'SAT',
#                 'price': 394,
#                 'return_at': '2024-06-10T00:59:00-07:00',
#                 'transfers': 1},
#  '2024-06-01': {'airline': 'UA',
#                 'departure_at': '2024-06-01T16:45:00-05:00',
#                 'destination': 'NYC',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 680,
#                 'origin': 'SAT',
#                 'price': 317,
#                 'return_at': '2024-06-05T12:31:00-04:00',
#                 'transfers': 1},
#  '2024-06-02': {'airline': 'DL',
#                 'departure_at': '2024-06-02T18:20:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1465,
#                 'origin': 'SAT',
#                 'price': 381,
#                 'return_at': '2024-06-06T08:00:00-04:00',
#                 'transfers': 1},
#  '2024-06-03': {'airline': 'DL',
#                 'departure_at': '2024-06-03T18:20:00-05:00',
#                 'destination': 'BOS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1465,
#                 'origin': 'SAT',
#                 'price': 318,
#                 'return_at': '2024-06-10T17:59:00-04:00',
#                 'transfers': 1},
#  '2024-06-04': {'airline': 'UA',
#                 'departure_at': '2024-06-04T14:15:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2496,
#                 'origin': 'SAT',
#                 'price': 221,
#                 'return_at': '2024-06-11T09:15:00-04:00',
#                 'transfers': 1},
#  '2024-06-05': {'airline': 'DL',
#                 'departure_at': '2024-06-05T18:20:00-05:00',
#                 'destination': 'BOS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1465,
#                 'origin': 'SAT',
#                 'price': 288,
#                 'return_at': '2024-06-10T17:59:00-04:00',
#                 'transfers': 1},
#  '2024-06-06': {'airline': 'DL',
#                 'departure_at': '2024-06-06T16:25:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1347,
#                 'origin': 'SAT',
#                 'price': 393,
#                 'return_at': '2024-06-10T19:59:00-04:00',
#                 'transfers': 1},
#  '2024-06-07': {'airline': 'UA',
#                 'departure_at': '2024-06-07T10:00:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2460,
#                 'origin': 'SAT',
#                 'price': 476,
#                 'return_at': '2024-06-11T09:15:00-04:00',
#                 'transfers': 1},
#  '2024-06-08': {'airline': 'AA',
#                 'departure_at': '2024-06-08T08:19:00-05:00',
#                 'destination': 'HNL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2070,
#                 'origin': 'SAT',
#                 'price': 684,
#                 'return_at': '2024-06-15T12:23:00-10:00',
#                 'transfers': 1},
#  '2024-06-09': {'airline': 'AA',
#                 'departure_at': '2024-06-09T07:24:00-05:00',
#                 'destination': 'HNL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2053,
#                 'origin': 'SAT',
#                 'price': 684,
#                 'return_at': '2024-06-15T12:23:00-10:00',
#                 'transfers': 1},
#  '2024-06-10': {'airline': 'UA',
#                 'departure_at': '2024-06-10T16:45:00-05:00',
#                 'destination': 'LAS',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 680,
#                 'origin': 'SAT',
#                 'price': 266,
#                 'return_at': '2024-06-13T07:17:00-07:00',
#                 'transfers': 1},
#  '2024-06-11': {'airline': 'AS',
#                 'departure_at': '2024-06-11T07:00:00-05:00',
#                 'destination': 'SEA',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 495,
#                 'origin': 'SAT',
#                 'price': 342,
#                 'return_at': '2024-06-11T11:00:00-07:00',
#                 'transfers': 0},
#  '2024-06-12': {'airline': 'DL',
#                 'departure_at': '2024-06-12T06:20:00-05:00',
#                 'destination': 'TYO',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 7699,
#                 'origin': 'SAT',
#                 'price': 1770,
#                 'return_at': '2024-06-13T18:30:00+09:00',
#                 'transfers': 2},
#  '2024-06-14': {'airline': 'UA',
#                 'departure_at': '2024-06-14T13:53:00-05:00',
#                 'destination': 'BKK',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 1269,
#                 'origin': 'SAT',
#                 'price': 5064,
#                 'return_at': '2024-06-28T01:45:00+07:00',
#                 'transfers': 2},
#  '2024-06-15': {'airline': 'UA',
#                 'departure_at': '2024-06-15T14:15:00-05:00',
#                 'destination': 'ORL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2496,
#                 'origin': 'SAT',
#                 'price': 1823,
#                 'return_at': '2024-06-20T17:10:00-04:00',
#                 'transfers': 1},
#  '2024-06-20': {'airline': 'UA',
#                 'departure_at': '2024-06-20T07:30:00-05:00',
#                 'destination': 'HNL',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2486,
#                 'origin': 'SAT',
#                 'price': 668,
#                 'return_at': '2024-06-29T07:00:00-10:00',
#                 'transfers': 1},
#  '2024-06-23': {'airline': 'UA',
#                 'departure_at': '2024-06-23T07:30:00-05:00',
#                 'destination': 'YYC',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2486,
#                 'origin': 'SAT',
#                 'price': 566,
#                 'return_at': '2024-06-29T12:30:00-06:00',
#                 'transfers': 1},
#  '2024-06-30': {'airline': 'UA',
#                 'departure_at': '2024-06-30T10:00:00-05:00',
#                 'destination': 'PHX',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2460,
#                 'origin': 'SAT',
#                 'price': 384,
#                 'return_at': '2024-07-04T12:05:00-07:00',
#                 'transfers': 1},
#  '2024-07-04': {'airline': 'UA',
#                 'departure_at': '2024-07-04T07:00:00-05:00',
#                 'destination': 'ATH',
#                 'expires_at': '2023-07-21T01:28:21Z',
#                 'flight_number': 2010,
#                 'origin': 'SAT',
#                 'price': 1690,
#                 'return_at': '2024-07-13T11:45:00+03:00',
#                 'transfers': 1}}

# %%
# Appending dates and currency values to inner dictionary
for dates in flights:
    flights[dates]['date'] = dates
    flights[dates]['currency'] = 'usd'

flights
# Out:
# {'2023-07-20': {'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 280,
#   'airline': 'NK',
#   'flight_number': 1044,
#   'departure_at': '2023-07-20T22:28:00-05:00',
#   'return_at': '2023-08-01T07:15:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-20',
#   'currency': 'usd'},
#  '2023-07-21': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 126,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-07-21T22:11:00-05:00',
#   'return_at': '2023-07-28T16:26:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-21',
#   'currency': 'usd'},
#  '2023-07-22': {'origin': 'SAT',
#   'destination': 'BWI',
#   'price': 150,
#   'airline': 'NK',
#   'flight_number': 1739,
#   'departure_at': '2023-07-22T16:00:00-05:00',
#   'return_at': '2023-08-05T21:19:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-22',
#   'currency': 'usd'},
#  '2023-07-23': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 115,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-07-23T22:23:00-05:00',
#   'return_at': '2023-07-28T16:26:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-23',
#   'currency': 'usd'},
#  '2023-07-24': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 170,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-07-24T21:07:00-05:00',
#   'return_at': '2023-07-28T09:20:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-24',
#   'currency': 'usd'},
#  '2023-07-25': {'origin': 'SAT',
#   'destination': 'ABI',
#   'price': 260,
#   'airline': 'AA',
#   'flight_number': 2342,
#   'departure_at': '2023-07-25T05:14:00-05:00',
#   'return_at': '2023-08-01T06:30:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-25',
#   'currency': 'usd'},
#  '2023-07-26': {'origin': 'SAT',
#   'destination': 'FLL',
#   'price': 128,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-07-26T07:00:00-05:00',
#   'return_at': '2023-08-02T13:30:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-26',
#   'currency': 'usd'},
#  '2023-07-27': {'origin': 'SAT',
#   'destination': 'CHI',
#   'price': 158,
#   'airline': 'F9',
#   'flight_number': 991,
#   'departure_at': '2023-07-27T10:28:00-05:00',
#   'return_at': '2023-07-29T22:51:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-27',
#   'currency': 'usd'},
#  '2023-07-28': {'origin': 'SAT',
#   'destination': 'FLL',
#   'price': 170,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-07-28T07:00:00-05:00',
#   'return_at': '2023-08-07T13:00:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-28',
#   'currency': 'usd'},
#  '2023-07-29': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 165,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-07-29T13:39:00-05:00',
#   'return_at': '2023-07-30T07:15:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-29',
#   'currency': 'usd'},
#  '2023-07-30': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 160,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-07-30T22:23:00-05:00',
#   'return_at': '2023-08-03T09:20:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-30',
#   'currency': 'usd'},
#  '2023-07-31': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 144,
#   'airline': 'G4',
#   'flight_number': 131,
#   'departure_at': '2023-07-31T21:53:00-05:00',
#   'return_at': '2023-08-03T09:20:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-31',
#   'currency': 'usd'},
#  '2023-08-01': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 141,
#   'airline': 'F9',
#   'flight_number': 1518,
#   'departure_at': '2023-08-01T17:47:00-05:00',
#   'return_at': '2023-08-12T09:05:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-01',
#   'currency': 'usd'},
#  '2023-08-02': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 155,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-08-02T14:50:00-05:00',
#   'return_at': '2023-08-02T19:40:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-02',
#   'currency': 'usd'},
#  '2023-08-03': {'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 124,
#   'airline': 'NK',
#   'flight_number': 1044,
#   'departure_at': '2023-08-03T22:28:00-05:00',
#   'return_at': '2023-08-05T14:15:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-03',
#   'currency': 'usd'},
#  '2023-08-04': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 115,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-08-04T08:58:00-05:00',
#   'return_at': '2023-08-07T05:35:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-04',
#   'currency': 'usd'},
#  '2023-08-05': {'origin': 'SAT',
#   'destination': 'FLL',
#   'price': 119,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-08-05T07:00:00-05:00',
#   'return_at': '2023-08-07T13:00:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-05',
#   'currency': 'usd'},
#  '2023-08-06': {'origin': 'SAT',
#   'destination': 'BWI',
#   'price': 142,
#   'airline': 'NK',
#   'flight_number': 1739,
#   'departure_at': '2023-08-06T16:00:00-05:00',
#   'return_at': '2023-08-12T10:16:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-06',
#   'currency': 'usd'},
#  '2023-08-07': {'origin': 'SAT',
#   'destination': 'BWI',
#   'price': 92,
#   'airline': 'NK',
#   'flight_number': 1739,
#   'departure_at': '2023-08-07T16:00:00-05:00',
#   'return_at': '2023-08-11T21:24:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-07',
#   'currency': 'usd'},
#  '2023-08-08': {'origin': 'SAT',
#   'destination': 'ATL',
#   'price': 75,
#   'airline': 'F9',
#   'flight_number': 1518,
#   'departure_at': '2023-08-08T17:42:00-05:00',
#   'return_at': '2023-08-15T15:23:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-08',
#   'currency': 'usd'},
#  '2023-08-09': {'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 159,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-08-09T14:51:00-05:00',
#   'return_at': '2023-08-12T15:07:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-09',
#   'currency': 'usd'},
#  '2023-08-10': {'origin': 'SAT',
#   'destination': 'BWI',
#   'price': 78,
#   'airline': 'NK',
#   'flight_number': 1739,
#   'departure_at': '2023-08-10T16:07:00-05:00',
#   'return_at': '2023-08-13T21:24:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-10',
#   'currency': 'usd'},
#  '2023-08-11': {'origin': 'SAT',
#   'destination': 'FLL',
#   'price': 109,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-08-11T07:00:00-05:00',
#   'return_at': '2023-08-16T16:59:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-11',
#   'currency': 'usd'},
#  '2023-08-12': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 147,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-08-12T14:51:00-05:00',
#   'return_at': '2023-08-15T09:05:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-12',
#   'currency': 'usd'},
#  '2023-08-13': {'origin': 'SAT',
#   'destination': 'AVL',
#   'price': 232,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-08-13T07:00:00-05:00',
#   'return_at': '2023-08-18T14:23:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-13',
#   'currency': 'usd'},
#  '2023-08-14': {'origin': 'SAT',
#   'destination': 'FLL',
#   'price': 120,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-08-14T07:00:00-05:00',
#   'return_at': '2023-08-21T13:05:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-14',
#   'currency': 'usd'},
#  '2023-08-15': {'origin': 'SAT',
#   'destination': 'RDU',
#   'price': 132,
#   'airline': 'F9',
#   'flight_number': 555,
#   'departure_at': '2023-08-15T20:07:00-05:00',
#   'return_at': '2023-08-19T05:45:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-15',
#   'currency': 'usd'},
#  '2023-08-16': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 155,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-08-16T19:41:00-05:00',
#   'return_at': '2023-08-20T09:05:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-16',
#   'currency': 'usd'},
#  '2023-08-17': {'origin': 'SAT',
#   'destination': 'ATL',
#   'price': 93,
#   'airline': 'F9',
#   'flight_number': 1518,
#   'departure_at': '2023-08-17T19:08:00-05:00',
#   'return_at': '2023-08-24T16:43:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-17',
#   'currency': 'usd'},
#  '2023-08-18': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 104,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-08-18T10:08:00-05:00',
#   'return_at': '2023-08-24T08:20:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-18',
#   'currency': 'usd'},
#  '2023-08-19': {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 160,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-08-19T07:00:00-05:00',
#   'return_at': '2023-08-23T06:00:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-19',
#   'currency': 'usd'},
#  '2023-08-20': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 137,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-08-20T20:17:00-05:00',
#   'return_at': '2023-08-25T15:53:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-20',
#   'currency': 'usd'},
#  '2023-08-21': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 101,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-08-21T16:59:00-05:00',
#   'return_at': '2023-08-25T07:20:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-21',
#   'currency': 'usd'},
#  '2023-08-22': {'origin': 'SAT',
#   'destination': 'DTT',
#   'price': 168,
#   'airline': 'F9',
#   'flight_number': 991,
#   'departure_at': '2023-08-22T21:38:00-05:00',
#   'return_at': '2023-08-29T13:35:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-22',
#   'currency': 'usd'},
#  '2023-08-23': {'origin': 'SAT',
#   'destination': 'TPA',
#   'price': 127,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-08-23T07:00:00-05:00',
#   'return_at': '2023-08-28T10:13:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-23',
#   'currency': 'usd'},
#  '2023-08-24': {'origin': 'SAT',
#   'destination': 'DEN',
#   'price': 90,
#   'airline': 'F9',
#   'flight_number': 991,
#   'departure_at': '2023-08-24T23:01:00-05:00',
#   'return_at': '2023-08-31T18:55:00-06:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-24',
#   'currency': 'usd'},
#  '2023-08-25': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 128,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-08-25T10:01:00-05:00',
#   'return_at': '2023-08-28T14:04:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-25',
#   'currency': 'usd'},
#  '2023-08-26': {'origin': 'SAT',
#   'destination': 'PDX',
#   'price': 262,
#   'airline': 'UA',
#   'flight_number': 1373,
#   'departure_at': '2023-08-26T16:24:00-05:00',
#   'return_at': '2023-09-02T07:12:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-26',
#   'currency': 'usd'},
#  '2023-08-27': {'origin': 'SAT',
#   'destination': 'HNL',
#   'price': 358,
#   'airline': 'UA',
#   'flight_number': 469,
#   'departure_at': '2023-08-27T05:15:00-05:00',
#   'return_at': '2023-08-30T19:55:00-10:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-27',
#   'currency': 'usd'},
#  '2023-08-28': {'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 162,
#   'airline': 'NK',
#   'flight_number': 1044,
#   'departure_at': '2023-08-28T20:59:00-05:00',
#   'return_at': '2023-08-29T12:44:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-28',
#   'currency': 'usd'},
#  '2023-08-29': {'origin': 'SAT',
#   'destination': 'MYR',
#   'price': 200,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-08-29T07:00:00-05:00',
#   'return_at': '2023-08-31T10:25:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-29',
#   'currency': 'usd'},
#  '2023-08-30': {'origin': 'SAT',
#   'destination': 'MEX',
#   'price': 216,
#   'airline': 'Y4',
#   'flight_number': 837,
#   'departure_at': '2023-08-30T13:35:00-05:00',
#   'return_at': '2023-09-02T12:20:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-30',
#   'currency': 'usd'},
#  '2023-08-31': {'origin': 'SAT',
#   'destination': 'DFW',
#   'price': 188,
#   'airline': 'UA',
#   'flight_number': 469,
#   'departure_at': '2023-08-31T05:15:00-05:00',
#   'return_at': '2023-09-02T17:48:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-31',
#   'currency': 'usd'},
#  '2023-09-01': {'origin': 'SAT',
#   'destination': 'ATL',
#   'price': 189,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-09-01T10:01:00-05:00',
#   'return_at': '2023-09-05T08:05:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-01',
#   'currency': 'usd'},
#  '2023-09-02': {'origin': 'SAT',
#   'destination': 'BWI',
#   'price': 128,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-09-02T12:09:00-05:00',
#   'return_at': '2023-09-04T21:24:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-02',
#   'currency': 'usd'},
#  '2023-09-03': {'origin': 'SAT',
#   'destination': 'MEX',
#   'price': 214,
#   'airline': 'Y4',
#   'flight_number': 837,
#   'departure_at': '2023-09-03T13:35:00-05:00',
#   'return_at': '2023-09-10T12:20:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-03',
#   'currency': 'usd'},
#  '2023-09-04': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 116,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-09-04T21:34:00-05:00',
#   'return_at': '2023-09-07T06:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-04',
#   'currency': 'usd'},
#  '2023-09-05': {'origin': 'SAT',
#   'destination': 'DEN',
#   'price': 87,
#   'airline': 'F9',
#   'flight_number': 991,
#   'departure_at': '2023-09-05T21:38:00-05:00',
#   'return_at': '2023-09-12T17:41:00-06:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-05',
#   'currency': 'usd'},
#  '2023-09-06': {'origin': 'SAT',
#   'destination': 'SAN',
#   'price': 167,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-09-06T21:41:00-05:00',
#   'return_at': '2023-09-20T08:27:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-06',
#   'currency': 'usd'},
#  '2023-09-07': {'origin': 'SAT',
#   'destination': 'CHI',
#   'price': 180,
#   'airline': 'F9',
#   'flight_number': 1518,
#   'departure_at': '2023-09-07T18:27:00-05:00',
#   'return_at': '2023-09-11T13:03:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-07',
#   'currency': 'usd'},
#  '2023-09-08': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 116,
#   'airline': 'F9',
#   'flight_number': 2103,
#   'departure_at': '2023-09-08T12:10:00-05:00',
#   'return_at': '2023-09-13T16:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-08',
#   'currency': 'usd'},
#  '2023-09-09': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 89,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-09-09T12:00:00-05:00',
#   'return_at': '2023-09-13T16:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-09',
#   'currency': 'usd'},
#  '2023-09-10': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 117,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-09-10T22:36:00-05:00',
#   'return_at': '2023-09-13T16:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-10',
#   'currency': 'usd'},
#  '2023-09-11': {'origin': 'SAT',
#   'destination': 'CAE',
#   'price': 390,
#   'airline': 'AA',
#   'flight_number': 2556,
#   'departure_at': '2023-09-11T06:15:00-05:00',
#   'return_at': '2023-09-13T16:19:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-11',
#   'currency': 'usd'},
#  '2023-09-12': {'origin': 'SAT',
#   'destination': 'MTY',
#   'price': 208,
#   'airline': 'VB',
#   'flight_number': 677,
#   'departure_at': '2023-09-12T21:00:00-05:00',
#   'return_at': '2023-09-18T08:25:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-12',
#   'currency': 'usd'},
#  '2023-09-13': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 100,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-09-13T14:31:00-05:00',
#   'return_at': '2023-09-19T09:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-13',
#   'currency': 'usd'},
#  '2023-09-14': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 130,
#   'airline': 'F9',
#   'flight_number': 1200,
#   'departure_at': '2023-09-14T19:46:00-05:00',
#   'return_at': '2023-09-17T17:15:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-14',
#   'currency': 'usd'},
#  '2023-09-15': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 115,
#   'airline': 'F9',
#   'flight_number': 2073,
#   'departure_at': '2023-09-15T21:41:00-05:00',
#   'return_at': '2023-09-17T06:10:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-15',
#   'currency': 'usd'},
#  '2023-09-16': {'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 96,
#   'airline': 'NK',
#   'flight_number': 1044,
#   'departure_at': '2023-09-16T20:20:00-05:00',
#   'return_at': '2023-09-18T13:28:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-16',
#   'currency': 'usd'},
#  '2023-09-17': {'origin': 'SAT',
#   'destination': 'DFW',
#   'price': 212,
#   'airline': 'AA',
#   'flight_number': 2759,
#   'departure_at': '2023-09-17T10:31:00-05:00',
#   'return_at': '2023-09-18T07:08:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-17',
#   'currency': 'usd'},
#  '2023-09-18': {'origin': 'SAT',
#   'destination': 'SDF',
#   'price': 173,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-09-18T07:00:00-05:00',
#   'return_at': '2023-09-23T11:38:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-18',
#   'currency': 'usd'},
#  '2023-09-19': {'origin': 'SAT',
#   'destination': 'DEN',
#   'price': 80,
#   'airline': 'F9',
#   'flight_number': 991,
#   'departure_at': '2023-09-19T21:53:00-05:00',
#   'return_at': '2023-09-24T17:24:00-06:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-19',
#   'currency': 'usd'},
#  '2023-09-20': {'origin': 'SAT',
#   'destination': 'ONT',
#   'price': 135,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-09-20T21:41:00-05:00',
#   'return_at': '2023-09-25T13:28:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-20',
#   'currency': 'usd'},
#  '2023-09-21': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 123,
#   'airline': 'F9',
#   'flight_number': 1200,
#   'departure_at': '2023-09-21T19:46:00-05:00',
#   'return_at': '2023-09-24T17:15:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-21',
#   'currency': 'usd'},
#  '2023-09-22': {'origin': 'SAT',
#   'destination': 'MEX',
#   'price': 221,
#   'airline': 'VB',
#   'flight_number': 165,
#   'departure_at': '2023-09-22T17:45:00-05:00',
#   'return_at': '2023-10-02T12:20:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-22',
#   'currency': 'usd'},
#  '2023-09-23': {'origin': 'SAT',
#   'destination': 'SAN',
#   'price': 132,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-09-23T14:31:00-05:00',
#   'return_at': '2023-09-26T12:51:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-23',
#   'currency': 'usd'},
#  '2023-09-24': {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 188,
#   'airline': 'F9',
#   'flight_number': 2103,
#   'departure_at': '2023-09-24T11:50:00-05:00',
#   'return_at': '2023-09-26T21:19:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-24',
#   'currency': 'usd'},
#  '2023-09-25': {'origin': 'SAT',
#   'destination': 'BWI',
#   'price': 97,
#   'airline': 'NK',
#   'flight_number': 2010,
#   'departure_at': '2023-09-25T12:40:00-05:00',
#   'return_at': '2023-09-29T09:03:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-25',
#   'currency': 'usd'},
#  '2023-09-26': {'origin': 'SAT',
#   'destination': 'PDX',
#   'price': 173,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-09-26T20:29:00-05:00',
#   'return_at': '2023-09-30T19:47:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-26',
#   'currency': 'usd'},
#  '2023-09-27': {'origin': 'SAT',
#   'destination': 'TPA',
#   'price': 131,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-09-27T07:00:00-05:00',
#   'return_at': '2023-09-30T10:10:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-27',
#   'currency': 'usd'},
#  '2023-09-28': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 120,
#   'airline': 'F9',
#   'flight_number': 1200,
#   'departure_at': '2023-09-28T19:46:00-05:00',
#   'return_at': '2023-09-30T08:20:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-28',
#   'currency': 'usd'},
#  '2023-09-29': {'origin': 'SAT',
#   'destination': 'TPA',
#   'price': 178,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-09-29T07:00:00-05:00',
#   'return_at': '2023-10-01T10:10:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-29',
#   'currency': 'usd'},
#  '2023-09-30': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 110,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-09-30T12:00:00-05:00',
#   'return_at': '2023-10-02T16:08:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-30',
#   'currency': 'usd'},
#  '2023-10-01': {'origin': 'SAT',
#   'destination': 'DFW',
#   'price': 237,
#   'airline': 'AA',
#   'flight_number': 1965,
#   'departure_at': '2023-10-01T09:14:00-05:00',
#   'return_at': '2023-10-08T09:30:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-01',
#   'currency': 'usd'},
#  '2023-10-02': {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 208,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-10-02T07:00:00-05:00',
#   'return_at': '2023-10-05T08:00:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-02',
#   'currency': 'usd'},
#  '2023-10-03': {'origin': 'SAT',
#   'destination': 'CHI',
#   'price': 232,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-10-03T07:00:00-05:00',
#   'return_at': '2023-10-05T10:45:00-05:00',
#   'transfers': 2,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-03',
#   'currency': 'usd'},
#  '2023-10-04': {'origin': 'SAT',
#   'destination': 'SFO',
#   'price': 222,
#   'airline': 'UA',
#   'flight_number': 2663,
#   'departure_at': '2023-10-04T05:45:00-05:00',
#   'return_at': '2023-10-04T23:50:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-04',
#   'currency': 'usd'},
#  '2023-10-05': {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 216,
#   'airline': 'AA',
#   'flight_number': 614,
#   'departure_at': '2023-10-05T19:01:00-05:00',
#   'return_at': '2023-10-08T05:19:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-05',
#   'currency': 'usd'},
#  '2023-10-06': {'origin': 'SAT',
#   'destination': 'PHX',
#   'price': 248,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-10-06T10:54:00-05:00',
#   'return_at': '2023-10-16T21:22:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-06',
#   'currency': 'usd'},
#  '2023-10-07': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 234,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-10-07T19:59:00-05:00',
#   'return_at': '2023-10-10T14:34:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-07',
#   'currency': 'usd'},
#  '2023-10-08': {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 311,
#   'airline': 'AA',
#   'flight_number': 2397,
#   'departure_at': '2023-10-08T05:00:00-05:00',
#   'return_at': '2023-10-08T23:56:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-08',
#   'currency': 'usd'},
#  '2023-10-09': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 142,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-10-09T10:54:00-05:00',
#   'return_at': '2023-10-16T08:00:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-09',
#   'currency': 'usd'},
#  '2023-10-10': {'origin': 'SAT',
#   'destination': 'DUB',
#   'price': 642,
#   'airline': 'UA',
#   'flight_number': 2460,
#   'departure_at': '2023-10-10T09:44:00-05:00',
#   'return_at': '2023-10-24T12:15:00+01:00',
#   'transfers': 2,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-10',
#   'currency': 'usd'},
#  '2023-10-11': {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 218,
#   'airline': 'B6',
#   'flight_number': 1826,
#   'departure_at': '2023-10-11T14:30:00-05:00',
#   'return_at': '2023-10-18T07:55:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-11',
#   'currency': 'usd'},
#  '2023-10-12': {'origin': 'SAT',
#   'destination': 'MSY',
#   'price': 171,
#   'airline': 'UA',
#   'flight_number': 469,
#   'departure_at': '2023-10-12T05:21:00-05:00',
#   'return_at': '2023-10-15T05:00:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-12',
#   'currency': 'usd'},
#  '2023-10-13': {'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 152,
#   'airline': 'NK',
#   'flight_number': 1044,
#   'departure_at': '2023-10-13T19:16:00-05:00',
#   'return_at': '2023-10-20T13:28:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-13',
#   'currency': 'usd'},
#  '2023-10-14': {'origin': 'SAT',
#   'destination': 'PHL',
#   'price': 181,
#   'airline': 'F9',
#   'flight_number': 991,
#   'departure_at': '2023-10-14T15:02:00-05:00',
#   'return_at': '2023-10-16T15:15:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-14',
#   'currency': 'usd'},
#  '2023-10-15': {'origin': 'SAT',
#   'destination': 'CHI',
#   'price': 186,
#   'airline': 'F9',
#   'flight_number': 991,
#   'departure_at': '2023-10-15T15:02:00-05:00',
#   'return_at': '2023-10-16T22:24:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-15',
#   'currency': 'usd'},
#  '2023-10-16': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 126,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-10-16T10:54:00-05:00',
#   'return_at': '2023-10-21T08:00:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-16',
#   'currency': 'usd'},
#  '2023-10-17': {'origin': 'SAT',
#   'destination': 'DEN',
#   'price': 87,
#   'airline': 'F9',
#   'flight_number': 991,
#   'departure_at': '2023-10-17T15:02:00-05:00',
#   'return_at': '2023-10-21T11:00:00-06:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-17',
#   'currency': 'usd'},
#  '2023-10-18': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 117,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-10-18T19:59:00-05:00',
#   'return_at': '2023-10-21T14:34:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-18',
#   'currency': 'usd'},
#  '2023-10-19': {'origin': 'SAT',
#   'destination': 'TPA',
#   'price': 164,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-10-19T07:00:00-05:00',
#   'return_at': '2023-10-23T10:13:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-19',
#   'currency': 'usd'},
#  '2023-10-20': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 297,
#   'airline': 'NK',
#   'flight_number': 1044,
#   'departure_at': '2023-10-20T19:16:00-05:00',
#   'return_at': '2023-10-22T05:46:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-20',
#   'currency': 'usd'},
#  '2023-10-21': {'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 132,
#   'airline': 'NK',
#   'flight_number': 1044,
#   'departure_at': '2023-10-21T20:13:00-05:00',
#   'return_at': '2023-10-23T13:28:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-21',
#   'currency': 'usd'},
#  '2023-10-22': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 154,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-10-22T21:09:00-05:00',
#   'return_at': '2023-10-26T14:34:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-22',
#   'currency': 'usd'},
#  '2023-10-23': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 146,
#   'airline': 'NK',
#   'flight_number': 1718,
#   'departure_at': '2023-10-23T11:10:00-05:00',
#   'return_at': '2023-10-27T08:20:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-23',
#   'currency': 'usd'},
#  '2023-10-24': {'origin': 'SAT',
#   'destination': 'GDL',
#   'price': 270,
#   'airline': 'VB',
#   'flight_number': 677,
#   'departure_at': '2023-10-24T20:55:00-05:00',
#   'return_at': '2023-10-27T07:00:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-24',
#   'currency': 'usd'},
#  '2023-10-25': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 127,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-10-25T10:54:00-05:00',
#   'return_at': '2023-10-30T08:00:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-25',
#   'currency': 'usd'},
#  '2023-10-26': {'origin': 'SAT',
#   'destination': 'BNA',
#   'price': 215,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-10-26T07:00:00-05:00',
#   'return_at': '2023-10-31T06:10:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-26',
#   'currency': 'usd'},
#  '2023-10-27': {'origin': 'SAT',
#   'destination': 'ATL',
#   'price': 205,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-10-27T10:54:00-05:00',
#   'return_at': '2023-10-29T22:44:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-27',
#   'currency': 'usd'},
#  '2023-10-28': {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 193,
#   'airline': 'UA',
#   'flight_number': 1715,
#   'departure_at': '2023-10-28T12:55:00-05:00',
#   'return_at': '2023-11-02T09:00:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-28',
#   'currency': 'usd'},
#  '2023-10-29': {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 189,
#   'airline': 'AA',
#   'flight_number': 2616,
#   'departure_at': '2023-10-29T05:00:00-05:00',
#   'return_at': '2023-11-01T18:14:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-29',
#   'currency': 'usd'},
#  '2023-10-30': {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 194,
#   'airline': 'AA',
#   'flight_number': 2380,
#   'departure_at': '2023-10-30T18:00:00-05:00',
#   'return_at': '2023-11-03T18:14:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-30',
#   'currency': 'usd'},
#  '2023-10-31': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 122,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-10-31T19:59:00-05:00',
#   'return_at': '2023-11-03T14:34:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-31',
#   'currency': 'usd'},
#  '2023-11-01': {'origin': 'SAT',
#   'destination': 'HNL',
#   'price': 461,
#   'airline': 'UA',
#   'flight_number': 1894,
#   'departure_at': '2023-11-01T07:00:00-05:00',
#   'return_at': '2023-11-08T08:00:00-10:00',
#   'transfers': 2,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-01',
#   'currency': 'usd'},
#  '2023-11-02': {'origin': 'SAT',
#   'destination': 'BIL',
#   'price': 336,
#   'airline': 'UA',
#   'flight_number': 1654,
#   'departure_at': '2023-11-02T08:46:00-05:00',
#   'return_at': '2023-11-05T06:00:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-02',
#   'currency': 'usd'},
#  '2023-11-03': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 245,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-11-03T14:31:00-05:00',
#   'return_at': '2023-11-05T04:46:00-08:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-03',
#   'currency': 'usd'},
#  '2023-11-04': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 107,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-11-04T19:59:00-05:00',
#   'return_at': '2023-11-08T14:34:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-04',
#   'currency': 'usd'},
#  '2023-11-05': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 131,
#   'airline': 'NK',
#   'flight_number': 1718,
#   'departure_at': '2023-11-05T11:10:00-06:00',
#   'return_at': '2023-11-11T08:20:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-05',
#   'currency': 'usd'},
#  '2023-11-06': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 162,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-11-06T19:59:00-06:00',
#   'return_at': '2023-11-10T09:00:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-06',
#   'currency': 'usd'},
#  '2023-11-07': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 115,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-11-07T19:59:00-06:00',
#   'return_at': '2023-11-09T14:34:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-07',
#   'currency': 'usd'},
#  '2023-11-08': {'origin': 'SAT',
#   'destination': 'DEN',
#   'price': 126,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-11-08T10:54:00-06:00',
#   'return_at': '2023-11-14T11:00:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-08',
#   'currency': 'usd'},
#  '2023-11-09': {'origin': 'SAT',
#   'destination': 'BZE',
#   'price': 482,
#   'airline': 'UA',
#   'flight_number': 6343,
#   'departure_at': '2023-11-09T19:39:00-06:00',
#   'return_at': '2023-11-14T13:45:00-06:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-09',
#   'currency': 'usd'},
#  '2023-11-10': {'origin': 'SAT',
#   'destination': 'SAN',
#   'price': 282,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-11-10T14:31:00-06:00',
#   'return_at': '2023-11-12T19:05:00-08:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-10',
#   'currency': 'usd'},
#  '2023-11-11': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 95,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-11-11T19:59:00-06:00',
#   'return_at': '2023-11-15T14:34:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-11',
#   'currency': 'usd'},
#  '2023-11-12': {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 316,
#   'airline': 'AA',
#   'flight_number': 2616,
#   'departure_at': '2023-11-12T05:00:00-06:00',
#   'return_at': '2023-11-16T12:30:00-08:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-12',
#   'currency': 'usd'},
#  '2023-11-13': {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 313,
#   'airline': 'UA',
#   'flight_number': 680,
#   'departure_at': '2023-11-13T16:17:00-06:00',
#   'return_at': '2023-11-17T07:00:00-08:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-13',
#   'currency': 'usd'},
#  '2023-11-14': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 312,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-11-14T19:59:00-06:00',
#   'return_at': '2023-11-20T17:33:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-14',
#   'currency': 'usd'},
#  '2023-11-15': {'origin': 'SAT',
#   'destination': 'HNL',
#   'price': 1133,
#   'airline': 'AA',
#   'flight_number': 6338,
#   'departure_at': '2023-11-15T07:00:00-06:00',
#   'return_at': '2023-11-25T08:00:00-10:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-15',
#   'currency': 'usd'},
#  '2023-11-16': {'origin': 'SAT',
#   'destination': 'LCH',
#   'price': 306,
#   'airline': 'UA',
#   'flight_number': 1491,
#   'departure_at': '2023-11-16T07:15:00-06:00',
#   'return_at': '2023-11-20T11:55:00-06:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-16',
#   'currency': 'usd'},
#  '2023-11-17': {'origin': 'SAT',
#   'destination': 'DEN',
#   'price': 352,
#   'airline': 'UA',
#   'flight_number': 680,
#   'departure_at': '2023-11-17T16:17:00-06:00',
#   'return_at': '2023-11-24T20:51:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-17',
#   'currency': 'usd'},
#  '2023-11-18': {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 299,
#   'airline': 'AA',
#   'flight_number': 671,
#   'departure_at': '2023-11-18T06:29:00-06:00',
#   'return_at': '2023-11-29T16:00:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-18',
#   'currency': 'usd'},
#  '2023-11-19': {'origin': 'SAT',
#   'destination': 'PVR',
#   'price': 330,
#   'airline': 'Y4',
#   'flight_number': 837,
#   'departure_at': '2023-11-19T10:20:00-06:00',
#   'return_at': '2023-11-24T22:10:00-06:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-19',
#   'currency': 'usd'},
#  '2023-11-20': {'origin': 'SAT',
#   'destination': 'BIL',
#   'price': 416,
#   'airline': 'UA',
#   'flight_number': 680,
#   'departure_at': '2023-11-20T16:17:00-06:00',
#   'return_at': '2023-11-27T18:05:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-20',
#   'currency': 'usd'},
#  '2023-11-21': {'origin': 'SAT',
#   'destination': 'COS',
#   'price': 208,
#   'airline': 'UA',
#   'flight_number': 2663,
#   'departure_at': '2023-11-21T05:25:00-06:00',
#   'return_at': '2023-11-24T15:30:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-21',
#   'currency': 'usd'},
#  '2023-11-22': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 324,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-11-22T14:38:00-06:00',
#   'return_at': '2023-11-26T09:05:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-22',
#   'currency': 'usd'},
#  '2023-11-23': {'origin': 'SAT',
#   'destination': 'PDX',
#   'price': 322,
#   'airline': 'UA',
#   'flight_number': 2663,
#   'departure_at': '2023-11-23T05:25:00-06:00',
#   'return_at': '2023-11-30T11:05:00-08:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-23',
#   'currency': 'usd'},
#  '2023-11-24': {'origin': 'SAT',
#   'destination': 'DEN',
#   'price': 324,
#   'airline': 'UA',
#   'flight_number': 1715,
#   'departure_at': '2023-11-24T13:25:00-06:00',
#   'return_at': '2023-12-20T10:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-24',
#   'currency': 'usd'},
#  '2023-11-25': {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 357,
#   'airline': 'DL',
#   'flight_number': 1422,
#   'departure_at': '2023-11-25T18:25:00-06:00',
#   'return_at': '2023-12-02T05:30:00-08:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-25',
#   'currency': 'usd'},
#  '2023-11-26': {'origin': 'SAT',
#   'destination': 'PTY',
#   'price': 420,
#   'airline': 'DL',
#   'flight_number': 1027,
#   'departure_at': '2023-11-26T05:40:00-06:00',
#   'return_at': '2023-12-17T15:25:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-26',
#   'currency': 'usd'},
#  '2023-11-27': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 271,
#   'airline': 'UA',
#   'flight_number': 6337,
#   'departure_at': '2023-11-27T14:20:00-06:00',
#   'return_at': '2023-12-01T15:10:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-27',
#   'currency': 'usd'},
#  '2023-11-28': {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 202,
#   'airline': 'UA',
#   'flight_number': 1741,
#   'departure_at': '2023-11-28T13:06:00-06:00',
#   'return_at': '2023-12-02T15:29:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-28',
#   'currency': 'usd'},
#  '2023-11-29': {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 186,
#   'airline': 'UA',
#   'flight_number': 1715,
#   'departure_at': '2023-11-29T13:25:00-06:00',
#   'return_at': '2023-12-05T16:25:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-29',
#   'currency': 'usd'},
#  '2023-11-30': {'origin': 'SAT',
#   'destination': 'BWI',
#   'price': 131,
#   'airline': 'NK',
#   'flight_number': 1739,
#   'departure_at': '2023-11-30T16:10:00-06:00',
#   'return_at': '2023-12-03T21:19:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-30',
#   'currency': 'usd'},
#  '2023-12-01': {'origin': 'SAT',
#   'destination': 'MEX',
#   'price': 248,
#   'airline': 'VB',
#   'flight_number': 165,
#   'departure_at': '2023-12-01T17:15:00-06:00',
#   'return_at': '2023-12-03T13:50:00-06:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-01',
#   'currency': 'usd'},
#  '2023-12-02': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 194,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-12-02T14:38:00-06:00',
#   'return_at': '2023-12-08T09:05:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-02',
#   'currency': 'usd'},
#  '2023-12-03': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 191,
#   'airline': 'NK',
#   'flight_number': 1718,
#   'departure_at': '2023-12-03T09:55:00-06:00',
#   'return_at': '2023-12-09T06:55:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-03',
#   'currency': 'usd'},
#  '2023-12-04': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 155,
#   'airline': 'NK',
#   'flight_number': 1718,
#   'departure_at': '2023-12-04T09:55:00-06:00',
#   'return_at': '2023-12-08T06:55:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-04',
#   'currency': 'usd'},
#  '2023-12-05': {'origin': 'SAT',
#   'destination': 'FLL',
#   'price': 176,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-12-05T07:00:00-06:00',
#   'return_at': '2023-12-11T13:05:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-05',
#   'currency': 'usd'},
#  '2023-12-06': {'origin': 'SAT',
#   'destination': 'FLL',
#   'price': 124,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-12-06T07:00:00-06:00',
#   'return_at': '2023-12-12T13:05:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-06',
#   'currency': 'usd'},
#  '2023-12-07': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 306,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-12-07T14:38:00-06:00',
#   'return_at': '2023-12-10T09:05:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-07',
#   'currency': 'usd'},
#  '2023-12-08': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 203,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-12-08T14:38:00-06:00',
#   'return_at': '2023-12-12T09:05:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-08',
#   'currency': 'usd'},
#  '2023-12-09': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 155,
#   'airline': 'NK',
#   'flight_number': 1718,
#   'departure_at': '2023-12-09T09:48:00-06:00',
#   'return_at': '2023-12-14T06:55:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-09',
#   'currency': 'usd'},
#  '2023-12-10': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 221,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-12-10T14:38:00-06:00',
#   'return_at': '2023-12-12T09:05:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-10',
#   'currency': 'usd'},
#  '2023-12-11': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 203,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-12-11T14:38:00-06:00',
#   'return_at': '2023-12-13T09:05:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-11',
#   'currency': 'usd'},
#  '2023-12-12': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 203,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-12-12T14:38:00-06:00',
#   'return_at': '2023-12-14T09:05:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-12',
#   'currency': 'usd'},
#  '2023-12-13': {'origin': 'SAT',
#   'destination': 'DFW',
#   'price': 176,
#   'airline': 'UA',
#   'flight_number': 469,
#   'departure_at': '2023-12-13T05:15:00-06:00',
#   'return_at': '2023-12-13T17:32:00-06:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-13',
#   'currency': 'usd'},
#  '2023-12-14': {'origin': 'SAT',
#   'destination': 'DEN',
#   'price': 299,
#   'airline': 'UA',
#   'flight_number': 680,
#   'departure_at': '2023-12-14T16:17:00-06:00',
#   'return_at': '2023-12-17T10:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-14',
#   'currency': 'usd'},
#  '2023-12-15': {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 287,
#   'airline': 'B6',
#   'flight_number': 1566,
#   'departure_at': '2023-12-15T17:42:00-06:00',
#   'return_at': '2023-12-23T15:18:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-15',
#   'currency': 'usd'},
#  '2023-12-16': {'origin': 'SAT',
#   'destination': 'GDL',
#   'price': 469,
#   'airline': 'AM',
#   'flight_number': 635,
#   'departure_at': '2023-12-16T17:30:00-06:00',
#   'return_at': '2023-12-30T11:22:00-06:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-16',
#   'currency': 'usd'},
#  '2023-12-17': {'origin': 'SAT',
#   'destination': 'CHI',
#   'price': 338,
#   'airline': 'UA',
#   'flight_number': 1894,
#   'departure_at': '2023-12-17T07:00:00-06:00',
#   'return_at': '2023-12-20T20:10:00-06:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-17',
#   'currency': 'usd'},
#  '2023-12-18': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 224,
#   'airline': 'UA',
#   'flight_number': 469,
#   'departure_at': '2023-12-18T05:15:00-06:00',
#   'return_at': '2023-12-23T06:00:00-08:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-18',
#   'currency': 'usd'},
#  '2023-12-19': {'origin': 'SAT',
#   'destination': 'SAL',
#   'price': 842,
#   'airline': 'AM',
#   'flight_number': 633,
#   'departure_at': '2023-12-19T12:20:00-06:00',
#   'return_at': '2024-01-01T14:39:00-06:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-19',
#   'currency': 'usd'},
#  '2023-12-20': {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 296,
#   'airline': 'UA',
#   'flight_number': 1347,
#   'departure_at': '2023-12-20T07:30:00-06:00',
#   'return_at': '2023-12-25T14:46:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-20',
# ...
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-04-28',
#   'currency': 'usd'},
#  '2024-04-29': {'origin': 'SAT',
#   'destination': 'CUN',
#   'price': 431,
#   'airline': 'AM',
#   'flight_number': 631,
#   'departure_at': '2024-04-29T07:55:00-05:00',
#   'return_at': '2024-05-04T12:30:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-04-29',
#   'currency': 'usd'},
#  '2024-04-30': {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 217,
#   'airline': 'DL',
#   'flight_number': 1056,
#   'departure_at': '2024-04-30T13:50:00-05:00',
#   'return_at': '2024-05-11T09:45:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-04-30',
#   'currency': 'usd'},
#  '2024-05-01': {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 226,
#   'airline': 'UA',
#   'flight_number': 1894,
#   'departure_at': '2024-05-01T07:00:00-05:00',
#   'return_at': '2024-05-07T17:00:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-01',
#   'currency': 'usd'},
#  '2024-05-02': {'origin': 'SAT',
#   'destination': 'SDF',
#   'price': 1011,
#   'airline': 'UA',
#   'flight_number': 2460,
#   'departure_at': '2024-05-02T10:00:00-05:00',
#   'return_at': '2024-05-06T09:32:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-02',
#   'currency': 'usd'},
#  '2024-05-03': {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 406,
#   'airline': 'UA',
#   'flight_number': 2460,
#   'departure_at': '2024-05-03T10:00:00-05:00',
#   'return_at': '2024-05-12T06:05:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-03',
#   'currency': 'usd'},
#  '2024-05-04': {'origin': 'SAT',
#   'destination': 'SJD',
#   'price': 487,
#   'airline': 'UA',
#   'flight_number': 1022,
#   'departure_at': '2024-05-04T19:00:00-05:00',
#   'return_at': '2024-05-08T10:00:00-06:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-04',
#   'currency': 'usd'},
#  '2024-05-05': {'origin': 'SAT',
#   'destination': 'FSD',
#   'price': 508,
#   'airline': 'DL',
#   'flight_number': 1347,
#   'departure_at': '2024-05-05T16:25:00-05:00',
#   'return_at': '2024-05-12T05:00:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-05',
#   'currency': 'usd'},
#  '2024-05-06': {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 277,
#   'airline': 'DL',
#   'flight_number': 1056,
#   'departure_at': '2024-05-06T13:50:00-05:00',
#   'return_at': '2024-05-22T09:45:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-06',
#   'currency': 'usd'},
#  '2024-05-07': {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 217,
#   'airline': 'UA',
#   'flight_number': 2010,
#   'departure_at': '2024-05-07T07:00:00-05:00',
#   'return_at': '2024-05-08T12:31:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-07',
#   'currency': 'usd'},
#  '2024-05-08': {'origin': 'SAT',
#   'destination': 'ANC',
#   'price': 536,
#   'airline': 'AS',
#   'flight_number': 494,
#   'departure_at': '2024-05-08T18:00:00-05:00',
#   'return_at': '2024-05-15T05:00:00-08:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-08',
#   'currency': 'usd'},
#  '2024-05-09': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 376,
#   'airline': 'DL',
#   'flight_number': 1465,
#   'departure_at': '2024-05-09T18:20:00-05:00',
#   'return_at': '2024-05-13T19:50:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-09',
#   'currency': 'usd'},
#  '2024-05-10': {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 335,
#   'airline': 'AS',
#   'flight_number': 495,
#   'departure_at': '2024-05-10T07:00:00-05:00',
#   'return_at': '2024-05-18T11:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-10',
#   'currency': 'usd'},
#  '2024-05-11': {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 358,
#   'airline': 'UA',
#   'flight_number': 2498,
#   'departure_at': '2024-05-11T12:24:00-05:00',
#   'return_at': '2024-05-25T05:20:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-11',
#   'currency': 'usd'},
#  '2024-05-12': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 221,
#   'airline': 'UA',
#   'flight_number': 2663,
#   'departure_at': '2024-05-12T05:45:00-05:00',
#   'return_at': '2024-05-18T07:17:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-12',
#   'currency': 'usd'},
#  '2024-05-13': {'origin': 'SAT',
#   'destination': 'SFO',
#   'price': 336,
#   'airline': 'DL',
#   'flight_number': 1422,
#   'departure_at': '2024-05-13T18:25:00-05:00',
#   'return_at': '2024-05-21T17:15:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-13',
#   'currency': 'usd'},
#  '2024-05-14': {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 222,
#   'airline': 'UA',
#   'flight_number': 1347,
#   'departure_at': '2024-05-14T07:30:00-05:00',
#   'return_at': '2024-05-29T12:31:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-14',
#   'currency': 'usd'},
#  '2024-05-15': {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 267,
#   'airline': 'UA',
#   'flight_number': 1347,
#   'departure_at': '2024-05-15T07:30:00-05:00',
#   'return_at': '2024-05-29T12:31:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-15',
#   'currency': 'usd'},
#  '2024-05-16': {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 360,
#   'airline': 'UA',
#   'flight_number': 1347,
#   'departure_at': '2024-05-16T07:30:00-05:00',
#   'return_at': '2024-05-28T12:30:00-04:00',
#   'transfers': 2,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-16',
#   'currency': 'usd'},
#  '2024-05-17': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 306,
#   'airline': 'DL',
#   'flight_number': 1408,
#   'departure_at': '2024-05-17T13:40:00-05:00',
#   'return_at': '2024-05-20T11:05:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-17',
#   'currency': 'usd'},
#  '2024-05-18': {'origin': 'SAT',
#   'destination': 'HAV',
#   'price': 369,
#   'airline': 'UA',
#   'flight_number': 469,
#   'departure_at': '2024-05-18T05:45:00-05:00',
#   'return_at': '2024-05-31T15:30:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-18',
#   'currency': 'usd'},
#  '2024-05-19': {'origin': 'SAT',
#   'destination': 'CUN',
#   'price': 431,
#   'airline': 'AM',
#   'flight_number': 631,
#   'departure_at': '2024-05-19T07:55:00-05:00',
#   'return_at': '2024-05-24T12:30:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-19',
#   'currency': 'usd'},
#  '2024-05-20': {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 396,
#   'airline': 'DL',
#   'flight_number': 1465,
#   'departure_at': '2024-05-20T18:20:00-05:00',
#   'return_at': '2024-06-03T06:00:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-20',
#   'currency': 'usd'},
#  '2024-05-21': {'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 394,
#   'airline': 'UA',
#   'flight_number': 2496,
#   'departure_at': '2024-05-21T14:15:00-05:00',
#   'return_at': '2024-05-26T09:10:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-21',
#   'currency': 'usd'},
#  '2024-05-22': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 221,
#   'airline': 'UA',
#   'flight_number': 2663,
#   'departure_at': '2024-05-22T05:45:00-05:00',
#   'return_at': '2024-05-28T07:17:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-22',
#   'currency': 'usd'},
#  '2024-05-23': {'origin': 'SAT',
#   'destination': 'ATL',
#   'price': 317,
#   'airline': 'UA',
#   'flight_number': 2496,
#   'departure_at': '2024-05-23T14:15:00-05:00',
#   'return_at': '2024-05-28T15:45:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-23',
#   'currency': 'usd'},
#  '2024-05-24': {'origin': 'SAT',
#   'destination': 'CUN',
#   'price': 431,
#   'airline': 'AM',
#   'flight_number': 631,
#   'departure_at': '2024-05-24T07:55:00-05:00',
#   'return_at': '2024-05-28T13:25:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-24',
#   'currency': 'usd'},
#  '2024-05-25': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 221,
#   'airline': 'UA',
#   'flight_number': 2663,
#   'departure_at': '2024-05-25T05:45:00-05:00',
#   'return_at': '2024-05-31T07:17:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-25',
#   'currency': 'usd'},
#  '2024-05-26': {'origin': 'SAT',
#   'destination': 'BTR',
#   'price': 248,
#   'airline': 'DL',
#   'flight_number': 1027,
#   'departure_at': '2024-05-26T05:40:00-05:00',
#   'return_at': '2024-06-01T06:00:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-26',
#   'currency': 'usd'},
#  '2024-05-27': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 266,
#   'airline': 'UA',
#   'flight_number': 2496,
#   'departure_at': '2024-05-27T14:15:00-05:00',
#   'return_at': '2024-06-01T07:05:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-27',
#   'currency': 'usd'},
#  '2024-05-28': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 389,
#   'airline': 'UA',
#   'flight_number': 680,
#   'departure_at': '2024-05-28T16:45:00-05:00',
#   'return_at': '2024-05-31T07:17:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-28',
#   'currency': 'usd'},
#  '2024-05-29': {'origin': 'SAT',
#   'destination': 'JTR',
#   'price': 1712,
#   'airline': 'AA',
#   'flight_number': 5571,
#   'departure_at': '2024-05-29T06:21:00-05:00',
#   'return_at': '2024-06-03T19:05:00+03:00',
#   'transfers': 2,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-29',
#   'currency': 'usd'},
#  '2024-05-30': {'origin': 'SAT',
#   'destination': 'REK',
#   'price': 1299,
#   'airline': 'UA',
#   'flight_number': 1894,
#   'departure_at': '2024-05-30T07:00:00-05:00',
#   'return_at': '2024-06-13T10:00:00Z',
#   'transfers': 2,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-30',
#   'currency': 'usd'},
#  '2024-05-31': {'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 394,
#   'airline': 'UA',
#   'flight_number': 1022,
#   'departure_at': '2024-05-31T19:00:00-05:00',
#   'return_at': '2024-06-10T00:59:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-31',
#   'currency': 'usd'},
#  '2024-06-01': {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 317,
#   'airline': 'UA',
#   'flight_number': 680,
#   'departure_at': '2024-06-01T16:45:00-05:00',
#   'return_at': '2024-06-05T12:31:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-01',
#   'currency': 'usd'},
#  '2024-06-02': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 381,
#   'airline': 'DL',
#   'flight_number': 1465,
#   'departure_at': '2024-06-02T18:20:00-05:00',
#   'return_at': '2024-06-06T08:00:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-02',
#   'currency': 'usd'},
#  '2024-06-03': {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 318,
#   'airline': 'DL',
#   'flight_number': 1465,
#   'departure_at': '2024-06-03T18:20:00-05:00',
#   'return_at': '2024-06-10T17:59:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-03',
#   'currency': 'usd'},
#  '2024-06-04': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 221,
#   'airline': 'UA',
#   'flight_number': 2496,
#   'departure_at': '2024-06-04T14:15:00-05:00',
#   'return_at': '2024-06-11T09:15:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-04',
#   'currency': 'usd'},
#  '2024-06-05': {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 288,
#   'airline': 'DL',
#   'flight_number': 1465,
#   'departure_at': '2024-06-05T18:20:00-05:00',
#   'return_at': '2024-06-10T17:59:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-05',
#   'currency': 'usd'},
#  '2024-06-06': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 393,
#   'airline': 'DL',
#   'flight_number': 1347,
#   'departure_at': '2024-06-06T16:25:00-05:00',
#   'return_at': '2024-06-10T19:59:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-06',
#   'currency': 'usd'},
#  '2024-06-07': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 476,
#   'airline': 'UA',
#   'flight_number': 2460,
#   'departure_at': '2024-06-07T10:00:00-05:00',
#   'return_at': '2024-06-11T09:15:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-07',
#   'currency': 'usd'},
#  '2024-06-08': {'origin': 'SAT',
#   'destination': 'HNL',
#   'price': 684,
#   'airline': 'AA',
#   'flight_number': 2070,
#   'departure_at': '2024-06-08T08:19:00-05:00',
#   'return_at': '2024-06-15T12:23:00-10:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-08',
#   'currency': 'usd'},
#  '2024-06-09': {'origin': 'SAT',
#   'destination': 'HNL',
#   'price': 684,
#   'airline': 'AA',
#   'flight_number': 2053,
#   'departure_at': '2024-06-09T07:24:00-05:00',
#   'return_at': '2024-06-15T12:23:00-10:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-09',
#   'currency': 'usd'},
#  '2024-06-10': {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 266,
#   'airline': 'UA',
#   'flight_number': 680,
#   'departure_at': '2024-06-10T16:45:00-05:00',
#   'return_at': '2024-06-13T07:17:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-10',
#   'currency': 'usd'},
#  '2024-06-11': {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 342,
#   'airline': 'AS',
#   'flight_number': 495,
#   'departure_at': '2024-06-11T07:00:00-05:00',
#   'return_at': '2024-06-11T11:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-11',
#   'currency': 'usd'},
#  '2024-06-12': {'origin': 'SAT',
#   'destination': 'TYO',
#   'price': 1770,
#   'airline': 'DL',
#   'flight_number': 7699,
#   'departure_at': '2024-06-12T06:20:00-05:00',
#   'return_at': '2024-06-13T18:30:00+09:00',
#   'transfers': 2,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-12',
#   'currency': 'usd'},
#  '2024-06-14': {'origin': 'SAT',
#   'destination': 'BKK',
#   'price': 5064,
#   'airline': 'UA',
#   'flight_number': 1269,
#   'departure_at': '2024-06-14T13:53:00-05:00',
#   'return_at': '2024-06-28T01:45:00+07:00',
#   'transfers': 2,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-14',
#   'currency': 'usd'},
#  '2024-06-15': {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 1823,
#   'airline': 'UA',
#   'flight_number': 2496,
#   'departure_at': '2024-06-15T14:15:00-05:00',
#   'return_at': '2024-06-20T17:10:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-15',
#   'currency': 'usd'},
#  '2024-06-20': {'origin': 'SAT',
#   'destination': 'HNL',
#   'price': 668,
#   'airline': 'UA',
#   'flight_number': 2486,
#   'departure_at': '2024-06-20T07:30:00-05:00',
#   'return_at': '2024-06-29T07:00:00-10:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-20',
#   'currency': 'usd'},
#  '2024-06-23': {'origin': 'SAT',
#   'destination': 'YYC',
#   'price': 566,
#   'airline': 'UA',
#   'flight_number': 2486,
#   'departure_at': '2024-06-23T07:30:00-05:00',
#   'return_at': '2024-06-29T12:30:00-06:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-23',
#   'currency': 'usd'},
#  '2024-06-30': {'origin': 'SAT',
#   'destination': 'PHX',
#   'price': 384,
#   'airline': 'UA',
#   'flight_number': 2460,
#   'departure_at': '2024-06-30T10:00:00-05:00',
#   'return_at': '2024-07-04T12:05:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-30',
#   'currency': 'usd'},
#  '2024-07-04': {'origin': 'SAT',
#   'destination': 'ATH',
#   'price': 1690,
#   'airline': 'UA',
#   'flight_number': 2010,
#   'departure_at': '2024-07-04T07:00:00-05:00',
#   'return_at': '2024-07-13T11:45:00+03:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-07-04',
#   'currency': 'usd'}}

# %%
# Extracting inner dictionaries into list
clean_flights = [flights[data] for data in flights]
clean_flights
# Out:
# [{'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 280,
#   'airline': 'NK',
#   'flight_number': 1044,
#   'departure_at': '2023-07-20T22:28:00-05:00',
#   'return_at': '2023-08-01T07:15:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-20',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 126,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-07-21T22:11:00-05:00',
#   'return_at': '2023-07-28T16:26:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-21',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BWI',
#   'price': 150,
#   'airline': 'NK',
#   'flight_number': 1739,
#   'departure_at': '2023-07-22T16:00:00-05:00',
#   'return_at': '2023-08-05T21:19:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-22',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 115,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-07-23T22:23:00-05:00',
#   'return_at': '2023-07-28T16:26:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-23',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 170,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-07-24T21:07:00-05:00',
#   'return_at': '2023-07-28T09:20:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-24',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ABI',
#   'price': 260,
#   'airline': 'AA',
#   'flight_number': 2342,
#   'departure_at': '2023-07-25T05:14:00-05:00',
#   'return_at': '2023-08-01T06:30:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-25',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'FLL',
#   'price': 128,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-07-26T07:00:00-05:00',
#   'return_at': '2023-08-02T13:30:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-26',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'CHI',
#   'price': 158,
#   'airline': 'F9',
#   'flight_number': 991,
#   'departure_at': '2023-07-27T10:28:00-05:00',
#   'return_at': '2023-07-29T22:51:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-27',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'FLL',
#   'price': 170,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-07-28T07:00:00-05:00',
#   'return_at': '2023-08-07T13:00:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-28',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 165,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-07-29T13:39:00-05:00',
#   'return_at': '2023-07-30T07:15:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-29',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 160,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-07-30T22:23:00-05:00',
#   'return_at': '2023-08-03T09:20:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-30',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 144,
#   'airline': 'G4',
#   'flight_number': 131,
#   'departure_at': '2023-07-31T21:53:00-05:00',
#   'return_at': '2023-08-03T09:20:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-07-31',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 141,
#   'airline': 'F9',
#   'flight_number': 1518,
#   'departure_at': '2023-08-01T17:47:00-05:00',
#   'return_at': '2023-08-12T09:05:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-01',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 155,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-08-02T14:50:00-05:00',
#   'return_at': '2023-08-02T19:40:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-02',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 124,
#   'airline': 'NK',
#   'flight_number': 1044,
#   'departure_at': '2023-08-03T22:28:00-05:00',
#   'return_at': '2023-08-05T14:15:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-03',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 115,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-08-04T08:58:00-05:00',
#   'return_at': '2023-08-07T05:35:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-04',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'FLL',
#   'price': 119,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-08-05T07:00:00-05:00',
#   'return_at': '2023-08-07T13:00:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-05',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BWI',
#   'price': 142,
#   'airline': 'NK',
#   'flight_number': 1739,
#   'departure_at': '2023-08-06T16:00:00-05:00',
#   'return_at': '2023-08-12T10:16:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-06',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BWI',
#   'price': 92,
#   'airline': 'NK',
#   'flight_number': 1739,
#   'departure_at': '2023-08-07T16:00:00-05:00',
#   'return_at': '2023-08-11T21:24:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-07',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ATL',
#   'price': 75,
#   'airline': 'F9',
#   'flight_number': 1518,
#   'departure_at': '2023-08-08T17:42:00-05:00',
#   'return_at': '2023-08-15T15:23:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-08',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 159,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-08-09T14:51:00-05:00',
#   'return_at': '2023-08-12T15:07:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-09',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BWI',
#   'price': 78,
#   'airline': 'NK',
#   'flight_number': 1739,
#   'departure_at': '2023-08-10T16:07:00-05:00',
#   'return_at': '2023-08-13T21:24:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-10',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'FLL',
#   'price': 109,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-08-11T07:00:00-05:00',
#   'return_at': '2023-08-16T16:59:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-11',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 147,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-08-12T14:51:00-05:00',
#   'return_at': '2023-08-15T09:05:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-12',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'AVL',
#   'price': 232,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-08-13T07:00:00-05:00',
#   'return_at': '2023-08-18T14:23:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-13',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'FLL',
#   'price': 120,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-08-14T07:00:00-05:00',
#   'return_at': '2023-08-21T13:05:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-14',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'RDU',
#   'price': 132,
#   'airline': 'F9',
#   'flight_number': 555,
#   'departure_at': '2023-08-15T20:07:00-05:00',
#   'return_at': '2023-08-19T05:45:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-15',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 155,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-08-16T19:41:00-05:00',
#   'return_at': '2023-08-20T09:05:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-16',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ATL',
#   'price': 93,
#   'airline': 'F9',
#   'flight_number': 1518,
#   'departure_at': '2023-08-17T19:08:00-05:00',
#   'return_at': '2023-08-24T16:43:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-17',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 104,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-08-18T10:08:00-05:00',
#   'return_at': '2023-08-24T08:20:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-18',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 160,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-08-19T07:00:00-05:00',
#   'return_at': '2023-08-23T06:00:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-19',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 137,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-08-20T20:17:00-05:00',
#   'return_at': '2023-08-25T15:53:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-20',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 101,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-08-21T16:59:00-05:00',
#   'return_at': '2023-08-25T07:20:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-21',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'DTT',
#   'price': 168,
#   'airline': 'F9',
#   'flight_number': 991,
#   'departure_at': '2023-08-22T21:38:00-05:00',
#   'return_at': '2023-08-29T13:35:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-22',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'TPA',
#   'price': 127,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-08-23T07:00:00-05:00',
#   'return_at': '2023-08-28T10:13:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-23',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'DEN',
#   'price': 90,
#   'airline': 'F9',
#   'flight_number': 991,
#   'departure_at': '2023-08-24T23:01:00-05:00',
#   'return_at': '2023-08-31T18:55:00-06:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-24',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 128,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-08-25T10:01:00-05:00',
#   'return_at': '2023-08-28T14:04:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-25',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'PDX',
#   'price': 262,
#   'airline': 'UA',
#   'flight_number': 1373,
#   'departure_at': '2023-08-26T16:24:00-05:00',
#   'return_at': '2023-09-02T07:12:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-26',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'HNL',
#   'price': 358,
#   'airline': 'UA',
#   'flight_number': 469,
#   'departure_at': '2023-08-27T05:15:00-05:00',
#   'return_at': '2023-08-30T19:55:00-10:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-27',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 162,
#   'airline': 'NK',
#   'flight_number': 1044,
#   'departure_at': '2023-08-28T20:59:00-05:00',
#   'return_at': '2023-08-29T12:44:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-28',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'MYR',
#   'price': 200,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-08-29T07:00:00-05:00',
#   'return_at': '2023-08-31T10:25:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-29',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'MEX',
#   'price': 216,
#   'airline': 'Y4',
#   'flight_number': 837,
#   'departure_at': '2023-08-30T13:35:00-05:00',
#   'return_at': '2023-09-02T12:20:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-30',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'DFW',
#   'price': 188,
#   'airline': 'UA',
#   'flight_number': 469,
#   'departure_at': '2023-08-31T05:15:00-05:00',
#   'return_at': '2023-09-02T17:48:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-08-31',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ATL',
#   'price': 189,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-09-01T10:01:00-05:00',
#   'return_at': '2023-09-05T08:05:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-01',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BWI',
#   'price': 128,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-09-02T12:09:00-05:00',
#   'return_at': '2023-09-04T21:24:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-02',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'MEX',
#   'price': 214,
#   'airline': 'Y4',
#   'flight_number': 837,
#   'departure_at': '2023-09-03T13:35:00-05:00',
#   'return_at': '2023-09-10T12:20:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-03',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 116,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-09-04T21:34:00-05:00',
#   'return_at': '2023-09-07T06:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-04',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'DEN',
#   'price': 87,
#   'airline': 'F9',
#   'flight_number': 991,
#   'departure_at': '2023-09-05T21:38:00-05:00',
#   'return_at': '2023-09-12T17:41:00-06:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-05',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SAN',
#   'price': 167,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-09-06T21:41:00-05:00',
#   'return_at': '2023-09-20T08:27:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-06',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'CHI',
#   'price': 180,
#   'airline': 'F9',
#   'flight_number': 1518,
#   'departure_at': '2023-09-07T18:27:00-05:00',
#   'return_at': '2023-09-11T13:03:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-07',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 116,
#   'airline': 'F9',
#   'flight_number': 2103,
#   'departure_at': '2023-09-08T12:10:00-05:00',
#   'return_at': '2023-09-13T16:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-08',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 89,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-09-09T12:00:00-05:00',
#   'return_at': '2023-09-13T16:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-09',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 117,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-09-10T22:36:00-05:00',
#   'return_at': '2023-09-13T16:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-10',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'CAE',
#   'price': 390,
#   'airline': 'AA',
#   'flight_number': 2556,
#   'departure_at': '2023-09-11T06:15:00-05:00',
#   'return_at': '2023-09-13T16:19:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-11',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'MTY',
#   'price': 208,
#   'airline': 'VB',
#   'flight_number': 677,
#   'departure_at': '2023-09-12T21:00:00-05:00',
#   'return_at': '2023-09-18T08:25:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-12',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 100,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-09-13T14:31:00-05:00',
#   'return_at': '2023-09-19T09:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-13',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 130,
#   'airline': 'F9',
#   'flight_number': 1200,
#   'departure_at': '2023-09-14T19:46:00-05:00',
#   'return_at': '2023-09-17T17:15:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-14',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 115,
#   'airline': 'F9',
#   'flight_number': 2073,
#   'departure_at': '2023-09-15T21:41:00-05:00',
#   'return_at': '2023-09-17T06:10:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-15',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 96,
#   'airline': 'NK',
#   'flight_number': 1044,
#   'departure_at': '2023-09-16T20:20:00-05:00',
#   'return_at': '2023-09-18T13:28:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-16',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'DFW',
#   'price': 212,
#   'airline': 'AA',
#   'flight_number': 2759,
#   'departure_at': '2023-09-17T10:31:00-05:00',
#   'return_at': '2023-09-18T07:08:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-17',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SDF',
#   'price': 173,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-09-18T07:00:00-05:00',
#   'return_at': '2023-09-23T11:38:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-18',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'DEN',
#   'price': 80,
#   'airline': 'F9',
#   'flight_number': 991,
#   'departure_at': '2023-09-19T21:53:00-05:00',
#   'return_at': '2023-09-24T17:24:00-06:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-19',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ONT',
#   'price': 135,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-09-20T21:41:00-05:00',
#   'return_at': '2023-09-25T13:28:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-20',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 123,
#   'airline': 'F9',
#   'flight_number': 1200,
#   'departure_at': '2023-09-21T19:46:00-05:00',
#   'return_at': '2023-09-24T17:15:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-21',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'MEX',
#   'price': 221,
#   'airline': 'VB',
#   'flight_number': 165,
#   'departure_at': '2023-09-22T17:45:00-05:00',
#   'return_at': '2023-10-02T12:20:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-22',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SAN',
#   'price': 132,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-09-23T14:31:00-05:00',
#   'return_at': '2023-09-26T12:51:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-23',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 188,
#   'airline': 'F9',
#   'flight_number': 2103,
#   'departure_at': '2023-09-24T11:50:00-05:00',
#   'return_at': '2023-09-26T21:19:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-24',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BWI',
#   'price': 97,
#   'airline': 'NK',
#   'flight_number': 2010,
#   'departure_at': '2023-09-25T12:40:00-05:00',
#   'return_at': '2023-09-29T09:03:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-25',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'PDX',
#   'price': 173,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-09-26T20:29:00-05:00',
#   'return_at': '2023-09-30T19:47:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-26',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'TPA',
#   'price': 131,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-09-27T07:00:00-05:00',
#   'return_at': '2023-09-30T10:10:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-27',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 120,
#   'airline': 'F9',
#   'flight_number': 1200,
#   'departure_at': '2023-09-28T19:46:00-05:00',
#   'return_at': '2023-09-30T08:20:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-28',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'TPA',
#   'price': 178,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-09-29T07:00:00-05:00',
#   'return_at': '2023-10-01T10:10:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-29',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 110,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-09-30T12:00:00-05:00',
#   'return_at': '2023-10-02T16:08:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-09-30',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'DFW',
#   'price': 237,
#   'airline': 'AA',
#   'flight_number': 1965,
#   'departure_at': '2023-10-01T09:14:00-05:00',
#   'return_at': '2023-10-08T09:30:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-01',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 208,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-10-02T07:00:00-05:00',
#   'return_at': '2023-10-05T08:00:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-02',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'CHI',
#   'price': 232,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-10-03T07:00:00-05:00',
#   'return_at': '2023-10-05T10:45:00-05:00',
#   'transfers': 2,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-03',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SFO',
#   'price': 222,
#   'airline': 'UA',
#   'flight_number': 2663,
#   'departure_at': '2023-10-04T05:45:00-05:00',
#   'return_at': '2023-10-04T23:50:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-04',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 216,
#   'airline': 'AA',
#   'flight_number': 614,
#   'departure_at': '2023-10-05T19:01:00-05:00',
#   'return_at': '2023-10-08T05:19:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-05',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'PHX',
#   'price': 248,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-10-06T10:54:00-05:00',
#   'return_at': '2023-10-16T21:22:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-06',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 234,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-10-07T19:59:00-05:00',
#   'return_at': '2023-10-10T14:34:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-07',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 311,
#   'airline': 'AA',
#   'flight_number': 2397,
#   'departure_at': '2023-10-08T05:00:00-05:00',
#   'return_at': '2023-10-08T23:56:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-08',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 142,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-10-09T10:54:00-05:00',
#   'return_at': '2023-10-16T08:00:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-09',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'DUB',
#   'price': 642,
#   'airline': 'UA',
#   'flight_number': 2460,
#   'departure_at': '2023-10-10T09:44:00-05:00',
#   'return_at': '2023-10-24T12:15:00+01:00',
#   'transfers': 2,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-10',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 218,
#   'airline': 'B6',
#   'flight_number': 1826,
#   'departure_at': '2023-10-11T14:30:00-05:00',
#   'return_at': '2023-10-18T07:55:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-11',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'MSY',
#   'price': 171,
#   'airline': 'UA',
#   'flight_number': 469,
#   'departure_at': '2023-10-12T05:21:00-05:00',
#   'return_at': '2023-10-15T05:00:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-12',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 152,
#   'airline': 'NK',
#   'flight_number': 1044,
#   'departure_at': '2023-10-13T19:16:00-05:00',
#   'return_at': '2023-10-20T13:28:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-13',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'PHL',
#   'price': 181,
#   'airline': 'F9',
#   'flight_number': 991,
#   'departure_at': '2023-10-14T15:02:00-05:00',
#   'return_at': '2023-10-16T15:15:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-14',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'CHI',
#   'price': 186,
#   'airline': 'F9',
#   'flight_number': 991,
#   'departure_at': '2023-10-15T15:02:00-05:00',
#   'return_at': '2023-10-16T22:24:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-15',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 126,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-10-16T10:54:00-05:00',
#   'return_at': '2023-10-21T08:00:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-16',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'DEN',
#   'price': 87,
#   'airline': 'F9',
#   'flight_number': 991,
#   'departure_at': '2023-10-17T15:02:00-05:00',
#   'return_at': '2023-10-21T11:00:00-06:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-17',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 117,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-10-18T19:59:00-05:00',
#   'return_at': '2023-10-21T14:34:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-18',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'TPA',
#   'price': 164,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-10-19T07:00:00-05:00',
#   'return_at': '2023-10-23T10:13:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-19',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 297,
#   'airline': 'NK',
#   'flight_number': 1044,
#   'departure_at': '2023-10-20T19:16:00-05:00',
#   'return_at': '2023-10-22T05:46:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-20',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 132,
#   'airline': 'NK',
#   'flight_number': 1044,
#   'departure_at': '2023-10-21T20:13:00-05:00',
#   'return_at': '2023-10-23T13:28:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-21',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 154,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-10-22T21:09:00-05:00',
#   'return_at': '2023-10-26T14:34:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-22',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 146,
#   'airline': 'NK',
#   'flight_number': 1718,
#   'departure_at': '2023-10-23T11:10:00-05:00',
#   'return_at': '2023-10-27T08:20:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-23',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'GDL',
#   'price': 270,
#   'airline': 'VB',
#   'flight_number': 677,
#   'departure_at': '2023-10-24T20:55:00-05:00',
#   'return_at': '2023-10-27T07:00:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-24',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 127,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-10-25T10:54:00-05:00',
#   'return_at': '2023-10-30T08:00:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-25',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BNA',
#   'price': 215,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-10-26T07:00:00-05:00',
#   'return_at': '2023-10-31T06:10:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-26',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ATL',
#   'price': 205,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-10-27T10:54:00-05:00',
#   'return_at': '2023-10-29T22:44:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-27',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 193,
#   'airline': 'UA',
#   'flight_number': 1715,
#   'departure_at': '2023-10-28T12:55:00-05:00',
#   'return_at': '2023-11-02T09:00:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-28',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 189,
#   'airline': 'AA',
#   'flight_number': 2616,
#   'departure_at': '2023-10-29T05:00:00-05:00',
#   'return_at': '2023-11-01T18:14:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-29',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 194,
#   'airline': 'AA',
#   'flight_number': 2380,
#   'departure_at': '2023-10-30T18:00:00-05:00',
#   'return_at': '2023-11-03T18:14:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-30',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 122,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-10-31T19:59:00-05:00',
#   'return_at': '2023-11-03T14:34:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-10-31',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'HNL',
#   'price': 461,
#   'airline': 'UA',
#   'flight_number': 1894,
#   'departure_at': '2023-11-01T07:00:00-05:00',
#   'return_at': '2023-11-08T08:00:00-10:00',
#   'transfers': 2,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-01',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BIL',
#   'price': 336,
#   'airline': 'UA',
#   'flight_number': 1654,
#   'departure_at': '2023-11-02T08:46:00-05:00',
#   'return_at': '2023-11-05T06:00:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-02',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 245,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-11-03T14:31:00-05:00',
#   'return_at': '2023-11-05T04:46:00-08:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-03',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 107,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-11-04T19:59:00-05:00',
#   'return_at': '2023-11-08T14:34:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-04',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 131,
#   'airline': 'NK',
#   'flight_number': 1718,
#   'departure_at': '2023-11-05T11:10:00-06:00',
#   'return_at': '2023-11-11T08:20:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-05',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 162,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-11-06T19:59:00-06:00',
#   'return_at': '2023-11-10T09:00:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-06',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 115,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-11-07T19:59:00-06:00',
#   'return_at': '2023-11-09T14:34:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-07',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'DEN',
#   'price': 126,
#   'airline': 'F9',
#   'flight_number': 1198,
#   'departure_at': '2023-11-08T10:54:00-06:00',
#   'return_at': '2023-11-14T11:00:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-08',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BZE',
#   'price': 482,
#   'airline': 'UA',
#   'flight_number': 6343,
#   'departure_at': '2023-11-09T19:39:00-06:00',
#   'return_at': '2023-11-14T13:45:00-06:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-09',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SAN',
#   'price': 282,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-11-10T14:31:00-06:00',
#   'return_at': '2023-11-12T19:05:00-08:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-10',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 95,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-11-11T19:59:00-06:00',
#   'return_at': '2023-11-15T14:34:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-11',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 316,
#   'airline': 'AA',
#   'flight_number': 2616,
#   'departure_at': '2023-11-12T05:00:00-06:00',
#   'return_at': '2023-11-16T12:30:00-08:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-12',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 313,
#   'airline': 'UA',
#   'flight_number': 680,
#   'departure_at': '2023-11-13T16:17:00-06:00',
#   'return_at': '2023-11-17T07:00:00-08:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-13',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 312,
#   'airline': 'F9',
#   'flight_number': 2075,
#   'departure_at': '2023-11-14T19:59:00-06:00',
#   'return_at': '2023-11-20T17:33:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-14',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'HNL',
#   'price': 1133,
#   'airline': 'AA',
#   'flight_number': 6338,
#   'departure_at': '2023-11-15T07:00:00-06:00',
#   'return_at': '2023-11-25T08:00:00-10:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-15',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LCH',
#   'price': 306,
#   'airline': 'UA',
#   'flight_number': 1491,
#   'departure_at': '2023-11-16T07:15:00-06:00',
#   'return_at': '2023-11-20T11:55:00-06:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-16',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'DEN',
#   'price': 352,
#   'airline': 'UA',
#   'flight_number': 680,
#   'departure_at': '2023-11-17T16:17:00-06:00',
#   'return_at': '2023-11-24T20:51:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-17',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 299,
#   'airline': 'AA',
#   'flight_number': 671,
#   'departure_at': '2023-11-18T06:29:00-06:00',
#   'return_at': '2023-11-29T16:00:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-18',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'PVR',
#   'price': 330,
#   'airline': 'Y4',
#   'flight_number': 837,
#   'departure_at': '2023-11-19T10:20:00-06:00',
#   'return_at': '2023-11-24T22:10:00-06:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-19',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BIL',
#   'price': 416,
#   'airline': 'UA',
#   'flight_number': 680,
#   'departure_at': '2023-11-20T16:17:00-06:00',
#   'return_at': '2023-11-27T18:05:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-20',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'COS',
#   'price': 208,
#   'airline': 'UA',
#   'flight_number': 2663,
#   'departure_at': '2023-11-21T05:25:00-06:00',
#   'return_at': '2023-11-24T15:30:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-21',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 324,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-11-22T14:38:00-06:00',
#   'return_at': '2023-11-26T09:05:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-22',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'PDX',
#   'price': 322,
#   'airline': 'UA',
#   'flight_number': 2663,
#   'departure_at': '2023-11-23T05:25:00-06:00',
#   'return_at': '2023-11-30T11:05:00-08:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-23',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'DEN',
#   'price': 324,
#   'airline': 'UA',
#   'flight_number': 1715,
#   'departure_at': '2023-11-24T13:25:00-06:00',
#   'return_at': '2023-12-20T10:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-24',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 357,
#   'airline': 'DL',
#   'flight_number': 1422,
#   'departure_at': '2023-11-25T18:25:00-06:00',
#   'return_at': '2023-12-02T05:30:00-08:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-25',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'PTY',
#   'price': 420,
#   'airline': 'DL',
#   'flight_number': 1027,
#   'departure_at': '2023-11-26T05:40:00-06:00',
#   'return_at': '2023-12-17T15:25:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-26',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 271,
#   'airline': 'UA',
#   'flight_number': 6337,
#   'departure_at': '2023-11-27T14:20:00-06:00',
#   'return_at': '2023-12-01T15:10:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-27',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 202,
#   'airline': 'UA',
#   'flight_number': 1741,
#   'departure_at': '2023-11-28T13:06:00-06:00',
#   'return_at': '2023-12-02T15:29:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-28',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 186,
#   'airline': 'UA',
#   'flight_number': 1715,
#   'departure_at': '2023-11-29T13:25:00-06:00',
#   'return_at': '2023-12-05T16:25:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-29',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BWI',
#   'price': 131,
#   'airline': 'NK',
#   'flight_number': 1739,
#   'departure_at': '2023-11-30T16:10:00-06:00',
#   'return_at': '2023-12-03T21:19:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-11-30',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'MEX',
#   'price': 248,
#   'airline': 'VB',
#   'flight_number': 165,
#   'departure_at': '2023-12-01T17:15:00-06:00',
#   'return_at': '2023-12-03T13:50:00-06:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-01',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 194,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-12-02T14:38:00-06:00',
#   'return_at': '2023-12-08T09:05:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-02',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 191,
#   'airline': 'NK',
#   'flight_number': 1718,
#   'departure_at': '2023-12-03T09:55:00-06:00',
#   'return_at': '2023-12-09T06:55:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-03',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 155,
#   'airline': 'NK',
#   'flight_number': 1718,
#   'departure_at': '2023-12-04T09:55:00-06:00',
#   'return_at': '2023-12-08T06:55:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-04',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'FLL',
#   'price': 176,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-12-05T07:00:00-06:00',
#   'return_at': '2023-12-11T13:05:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-05',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'FLL',
#   'price': 124,
#   'airline': 'NK',
#   'flight_number': 1737,
#   'departure_at': '2023-12-06T07:00:00-06:00',
#   'return_at': '2023-12-12T13:05:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-06',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 306,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-12-07T14:38:00-06:00',
#   'return_at': '2023-12-10T09:05:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-07',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 203,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-12-08T14:38:00-06:00',
#   'return_at': '2023-12-12T09:05:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-08',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 155,
#   'airline': 'NK',
#   'flight_number': 1718,
#   'departure_at': '2023-12-09T09:48:00-06:00',
#   'return_at': '2023-12-14T06:55:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-09',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 221,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-12-10T14:38:00-06:00',
#   'return_at': '2023-12-12T09:05:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-10',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 203,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-12-11T14:38:00-06:00',
#   'return_at': '2023-12-13T09:05:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-11',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 203,
#   'airline': 'NK',
#   'flight_number': 1039,
#   'departure_at': '2023-12-12T14:38:00-06:00',
#   'return_at': '2023-12-14T09:05:00-08:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-12',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'DFW',
#   'price': 176,
#   'airline': 'UA',
#   'flight_number': 469,
#   'departure_at': '2023-12-13T05:15:00-06:00',
#   'return_at': '2023-12-13T17:32:00-06:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-13',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'DEN',
#   'price': 299,
#   'airline': 'UA',
#   'flight_number': 680,
#   'departure_at': '2023-12-14T16:17:00-06:00',
#   'return_at': '2023-12-17T10:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-14',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 287,
#   'airline': 'B6',
#   'flight_number': 1566,
#   'departure_at': '2023-12-15T17:42:00-06:00',
#   'return_at': '2023-12-23T15:18:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-15',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'GDL',
#   'price': 469,
#   'airline': 'AM',
#   'flight_number': 635,
#   'departure_at': '2023-12-16T17:30:00-06:00',
#   'return_at': '2023-12-30T11:22:00-06:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-16',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'CHI',
#   'price': 338,
#   'airline': 'UA',
#   'flight_number': 1894,
#   'departure_at': '2023-12-17T07:00:00-06:00',
#   'return_at': '2023-12-20T20:10:00-06:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-17',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 224,
#   'airline': 'UA',
#   'flight_number': 469,
#   'departure_at': '2023-12-18T05:15:00-06:00',
#   'return_at': '2023-12-23T06:00:00-08:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-18',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SAL',
#   'price': 842,
#   'airline': 'AM',
#   'flight_number': 633,
#   'departure_at': '2023-12-19T12:20:00-06:00',
#   'return_at': '2024-01-01T14:39:00-06:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-19',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 296,
#   'airline': 'UA',
#   'flight_number': 1347,
#   'departure_at': '2023-12-20T07:30:00-06:00',
#   'return_at': '2023-12-25T14:46:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-20',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 296,
#   'airline': 'UA',
#   'flight_number': 680,
#   'departure_at': '2023-12-21T16:45:00-06:00',
#   'return_at': '2023-12-25T10:25:00-08:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-21',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 360,
#   'airline': 'UA',
#   'flight_number': 1347,
#   'departure_at': '2023-12-22T07:30:00-06:00',
#   'return_at': '2023-12-25T14:46:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-22',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 324,
#   'airline': 'B6',
#   'flight_number': 1826,
#   'departure_at': '2023-12-23T14:42:00-06:00',
#   'return_at': '2023-12-26T10:30:00-05:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-23',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 260,
#   'airline': 'UA',
#   'flight_number': 2250,
#   'departure_at': '2023-12-24T11:45:00-06:00',
#   'return_at': '2023-12-27T10:30:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-24',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'CHI',
#   'price': 278,
#   'airline': 'UA',
#   'flight_number': 1894,
#   'departure_at': '2023-12-25T07:00:00-06:00',
#   'return_at': '2023-12-31T08:57:00-06:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-25',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'DEN',
#   'price': 360,
#   'airline': 'UA',
#   'flight_number': 2496,
#   'departure_at': '2023-12-26T14:15:00-06:00',
#   'return_at': '2023-12-30T18:00:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-26',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 357,
#   'airline': 'UA',
#   'flight_number': 1347,
#   'departure_at': '2023-12-27T07:30:00-06:00',
#   'return_at': '2023-12-28T10:30:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2023-12-27',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 326,
# ...
#   'departure_at': '2024-04-26T16:20:00-05:00',
#   'return_at': '2024-04-29T12:45:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-04-26',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 238,
#   'airline': 'UA',
#   'flight_number': 680,
#   'departure_at': '2024-04-27T16:45:00-05:00',
#   'return_at': '2024-05-01T08:40:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-04-27',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 347,
#   'airline': 'B6',
#   'flight_number': 1826,
#   'departure_at': '2024-04-28T14:40:00-05:00',
#   'return_at': '2024-05-02T11:30:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-04-28',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'CUN',
#   'price': 431,
#   'airline': 'AM',
#   'flight_number': 631,
#   'departure_at': '2024-04-29T07:55:00-05:00',
#   'return_at': '2024-05-04T12:30:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-04-29',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 217,
#   'airline': 'DL',
#   'flight_number': 1056,
#   'departure_at': '2024-04-30T13:50:00-05:00',
#   'return_at': '2024-05-11T09:45:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-04-30',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 226,
#   'airline': 'UA',
#   'flight_number': 1894,
#   'departure_at': '2024-05-01T07:00:00-05:00',
#   'return_at': '2024-05-07T17:00:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-01',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SDF',
#   'price': 1011,
#   'airline': 'UA',
#   'flight_number': 2460,
#   'departure_at': '2024-05-02T10:00:00-05:00',
#   'return_at': '2024-05-06T09:32:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-02',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 406,
#   'airline': 'UA',
#   'flight_number': 2460,
#   'departure_at': '2024-05-03T10:00:00-05:00',
#   'return_at': '2024-05-12T06:05:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-03',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SJD',
#   'price': 487,
#   'airline': 'UA',
#   'flight_number': 1022,
#   'departure_at': '2024-05-04T19:00:00-05:00',
#   'return_at': '2024-05-08T10:00:00-06:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-04',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'FSD',
#   'price': 508,
#   'airline': 'DL',
#   'flight_number': 1347,
#   'departure_at': '2024-05-05T16:25:00-05:00',
#   'return_at': '2024-05-12T05:00:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-05',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 277,
#   'airline': 'DL',
#   'flight_number': 1056,
#   'departure_at': '2024-05-06T13:50:00-05:00',
#   'return_at': '2024-05-22T09:45:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-06',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 217,
#   'airline': 'UA',
#   'flight_number': 2010,
#   'departure_at': '2024-05-07T07:00:00-05:00',
#   'return_at': '2024-05-08T12:31:00-04:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-07',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ANC',
#   'price': 536,
#   'airline': 'AS',
#   'flight_number': 494,
#   'departure_at': '2024-05-08T18:00:00-05:00',
#   'return_at': '2024-05-15T05:00:00-08:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-08',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 376,
#   'airline': 'DL',
#   'flight_number': 1465,
#   'departure_at': '2024-05-09T18:20:00-05:00',
#   'return_at': '2024-05-13T19:50:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-09',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 335,
#   'airline': 'AS',
#   'flight_number': 495,
#   'departure_at': '2024-05-10T07:00:00-05:00',
#   'return_at': '2024-05-18T11:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-10',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 358,
#   'airline': 'UA',
#   'flight_number': 2498,
#   'departure_at': '2024-05-11T12:24:00-05:00',
#   'return_at': '2024-05-25T05:20:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-11',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 221,
#   'airline': 'UA',
#   'flight_number': 2663,
#   'departure_at': '2024-05-12T05:45:00-05:00',
#   'return_at': '2024-05-18T07:17:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-12',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SFO',
#   'price': 336,
#   'airline': 'DL',
#   'flight_number': 1422,
#   'departure_at': '2024-05-13T18:25:00-05:00',
#   'return_at': '2024-05-21T17:15:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-13',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 222,
#   'airline': 'UA',
#   'flight_number': 1347,
#   'departure_at': '2024-05-14T07:30:00-05:00',
#   'return_at': '2024-05-29T12:31:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-14',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 267,
#   'airline': 'UA',
#   'flight_number': 1347,
#   'departure_at': '2024-05-15T07:30:00-05:00',
#   'return_at': '2024-05-29T12:31:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-15',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 360,
#   'airline': 'UA',
#   'flight_number': 1347,
#   'departure_at': '2024-05-16T07:30:00-05:00',
#   'return_at': '2024-05-28T12:30:00-04:00',
#   'transfers': 2,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-16',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 306,
#   'airline': 'DL',
#   'flight_number': 1408,
#   'departure_at': '2024-05-17T13:40:00-05:00',
#   'return_at': '2024-05-20T11:05:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-17',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'HAV',
#   'price': 369,
#   'airline': 'UA',
#   'flight_number': 469,
#   'departure_at': '2024-05-18T05:45:00-05:00',
#   'return_at': '2024-05-31T15:30:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-18',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'CUN',
#   'price': 431,
#   'airline': 'AM',
#   'flight_number': 631,
#   'departure_at': '2024-05-19T07:55:00-05:00',
#   'return_at': '2024-05-24T12:30:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-19',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 396,
#   'airline': 'DL',
#   'flight_number': 1465,
#   'departure_at': '2024-05-20T18:20:00-05:00',
#   'return_at': '2024-06-03T06:00:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-20',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 394,
#   'airline': 'UA',
#   'flight_number': 2496,
#   'departure_at': '2024-05-21T14:15:00-05:00',
#   'return_at': '2024-05-26T09:10:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-21',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 221,
#   'airline': 'UA',
#   'flight_number': 2663,
#   'departure_at': '2024-05-22T05:45:00-05:00',
#   'return_at': '2024-05-28T07:17:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-22',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ATL',
#   'price': 317,
#   'airline': 'UA',
#   'flight_number': 2496,
#   'departure_at': '2024-05-23T14:15:00-05:00',
#   'return_at': '2024-05-28T15:45:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-23',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'CUN',
#   'price': 431,
#   'airline': 'AM',
#   'flight_number': 631,
#   'departure_at': '2024-05-24T07:55:00-05:00',
#   'return_at': '2024-05-28T13:25:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-24',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 221,
#   'airline': 'UA',
#   'flight_number': 2663,
#   'departure_at': '2024-05-25T05:45:00-05:00',
#   'return_at': '2024-05-31T07:17:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-25',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BTR',
#   'price': 248,
#   'airline': 'DL',
#   'flight_number': 1027,
#   'departure_at': '2024-05-26T05:40:00-05:00',
#   'return_at': '2024-06-01T06:00:00-05:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-26',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 266,
#   'airline': 'UA',
#   'flight_number': 2496,
#   'departure_at': '2024-05-27T14:15:00-05:00',
#   'return_at': '2024-06-01T07:05:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-27',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 389,
#   'airline': 'UA',
#   'flight_number': 680,
#   'departure_at': '2024-05-28T16:45:00-05:00',
#   'return_at': '2024-05-31T07:17:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-28',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'JTR',
#   'price': 1712,
#   'airline': 'AA',
#   'flight_number': 5571,
#   'departure_at': '2024-05-29T06:21:00-05:00',
#   'return_at': '2024-06-03T19:05:00+03:00',
#   'transfers': 2,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-29',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'REK',
#   'price': 1299,
#   'airline': 'UA',
#   'flight_number': 1894,
#   'departure_at': '2024-05-30T07:00:00-05:00',
#   'return_at': '2024-06-13T10:00:00Z',
#   'transfers': 2,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-30',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAX',
#   'price': 394,
#   'airline': 'UA',
#   'flight_number': 1022,
#   'departure_at': '2024-05-31T19:00:00-05:00',
#   'return_at': '2024-06-10T00:59:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-05-31',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'NYC',
#   'price': 317,
#   'airline': 'UA',
#   'flight_number': 680,
#   'departure_at': '2024-06-01T16:45:00-05:00',
#   'return_at': '2024-06-05T12:31:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-01',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 381,
#   'airline': 'DL',
#   'flight_number': 1465,
#   'departure_at': '2024-06-02T18:20:00-05:00',
#   'return_at': '2024-06-06T08:00:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-02',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 318,
#   'airline': 'DL',
#   'flight_number': 1465,
#   'departure_at': '2024-06-03T18:20:00-05:00',
#   'return_at': '2024-06-10T17:59:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-03',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 221,
#   'airline': 'UA',
#   'flight_number': 2496,
#   'departure_at': '2024-06-04T14:15:00-05:00',
#   'return_at': '2024-06-11T09:15:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-04',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BOS',
#   'price': 288,
#   'airline': 'DL',
#   'flight_number': 1465,
#   'departure_at': '2024-06-05T18:20:00-05:00',
#   'return_at': '2024-06-10T17:59:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-05',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 393,
#   'airline': 'DL',
#   'flight_number': 1347,
#   'departure_at': '2024-06-06T16:25:00-05:00',
#   'return_at': '2024-06-10T19:59:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-06',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 476,
#   'airline': 'UA',
#   'flight_number': 2460,
#   'departure_at': '2024-06-07T10:00:00-05:00',
#   'return_at': '2024-06-11T09:15:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-07',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'HNL',
#   'price': 684,
#   'airline': 'AA',
#   'flight_number': 2070,
#   'departure_at': '2024-06-08T08:19:00-05:00',
#   'return_at': '2024-06-15T12:23:00-10:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-08',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'HNL',
#   'price': 684,
#   'airline': 'AA',
#   'flight_number': 2053,
#   'departure_at': '2024-06-09T07:24:00-05:00',
#   'return_at': '2024-06-15T12:23:00-10:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-09',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'LAS',
#   'price': 266,
#   'airline': 'UA',
#   'flight_number': 680,
#   'departure_at': '2024-06-10T16:45:00-05:00',
#   'return_at': '2024-06-13T07:17:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-10',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'SEA',
#   'price': 342,
#   'airline': 'AS',
#   'flight_number': 495,
#   'departure_at': '2024-06-11T07:00:00-05:00',
#   'return_at': '2024-06-11T11:00:00-07:00',
#   'transfers': 0,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-11',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'TYO',
#   'price': 1770,
#   'airline': 'DL',
#   'flight_number': 7699,
#   'departure_at': '2024-06-12T06:20:00-05:00',
#   'return_at': '2024-06-13T18:30:00+09:00',
#   'transfers': 2,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-12',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'BKK',
#   'price': 5064,
#   'airline': 'UA',
#   'flight_number': 1269,
#   'departure_at': '2024-06-14T13:53:00-05:00',
#   'return_at': '2024-06-28T01:45:00+07:00',
#   'transfers': 2,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-14',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ORL',
#   'price': 1823,
#   'airline': 'UA',
#   'flight_number': 2496,
#   'departure_at': '2024-06-15T14:15:00-05:00',
#   'return_at': '2024-06-20T17:10:00-04:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-15',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'HNL',
#   'price': 668,
#   'airline': 'UA',
#   'flight_number': 2486,
#   'departure_at': '2024-06-20T07:30:00-05:00',
#   'return_at': '2024-06-29T07:00:00-10:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-20',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'YYC',
#   'price': 566,
#   'airline': 'UA',
#   'flight_number': 2486,
#   'departure_at': '2024-06-23T07:30:00-05:00',
#   'return_at': '2024-06-29T12:30:00-06:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-23',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'PHX',
#   'price': 384,
#   'airline': 'UA',
#   'flight_number': 2460,
#   'departure_at': '2024-06-30T10:00:00-05:00',
#   'return_at': '2024-07-04T12:05:00-07:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-06-30',
#   'currency': 'usd'},
#  {'origin': 'SAT',
#   'destination': 'ATH',
#   'price': 1690,
#   'airline': 'UA',
#   'flight_number': 2010,
#   'departure_at': '2024-07-04T07:00:00-05:00',
#   'return_at': '2024-07-13T11:45:00+03:00',
#   'transfers': 1,
#   'expires_at': '2023-07-21T01:28:21Z',
#   'date': '2024-07-04',
#   'currency': 'usd'}]

# %%
# Writing clean data into new json file
with open('Resources/clean_data.json', 'w') as openfile:
    json.dump(clean_flights, openfile)

# %% [markdown]
# ## Mongodb

# %%
# Creating an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'local', 'sa_vacations', 'uk_food']

# %%
# Assigning database to a variable
db = mongo['sa_vacations']

# %%
# Reviewing collections in database
db.list_collection_names()
# Out:
# ['flights']
